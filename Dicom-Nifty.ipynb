# %% [markdown]
# # Manentia's DICOM to NIfTI and NIfTI to DICOM conversion Task
#
#
# Complete the Python code of the given two classes.
#
# `Python version >= 3.10`
#
# ### Download two test samples from here:
# 1. https://drive.google.com/file/d/1PqTEEFc0YbV7iCF8rDYRltE-Y4h95V-E/view?usp=sharing
# 2. https://drive.google.com/file/d/1ifdNew-8qXGKASZ58KIB5OHde89yEUB2/view?usp=sharing
#
# Note: In sample 2, there are multiple series. Choose only one with the maximum number of slices to pass to DICOMToNIfTI(series_path) argument

# %%
# !pip install pydicom
# %pip install pylibjpeg
# Out:
# Collecting pylibjpeg
#   Downloading pylibjpeg-2.1.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pylibjpeg) (2.0.2)
# Downloading pylibjpeg-2.1.0-py3-none-any.whl (25 kB)
# Installing collected packages: pylibjpeg
# Successfully installed pylibjpeg-2.1.0

# %%
from attrs import define, field, validators
from __future__ import annotations
from pathlib import Path
from pydicom import dcmread
import numpy as np
import nibabel as nib
import datetime
import pylibjpeg

@define
class DICOMToNIfTI:
    series_paths: list[str | Path] = field()
    save_dirpath: str | Path = field(default="mai_output", converter=Path)

    def convert(self):
        # Load CT series
        ds_list = []
        for filepath in self.series_paths:
            ds = dcmread(filepath)
            print(f"{ds.get('ImagePositionPatient')[-1] = }")
            ds_list.append(ds)

        # TODO: Sort the CT slices using ImagePositionPatient
        ds_list.sort(key=lambda ds: ds.ImagePositionPatient[-1])


        volm, meta_list = [], []
        for ds in ds_list:
            volm.append(ds.pixel_array)
            meta_list.append({
                'patient_id': ds.get('PatientID'),
                'study_uid': ds.get('StudyInstanceUID'),
                'series_uid': ds.get('SeriesInstanceUID'),
                'modality': ds.get('Modality'),
                'bodypart': ds.get('BodyPartExamined'),
                'rows': ds.get('Rows'),
                'cols': ds.get('Columns'),
                'imagepositionpatient': ds.get('ImagePositionPatient'), # if 'ImagePositionPatient' in ds else None,
                'transfer_syntax_uid': ds.file_meta.TransferSyntaxUID,
                'samples_per_pixel': ds.get('SamplesPerPixel'),
                'bits_allocated' : ds.get('BitsAllocated'),
                'pixel_representation' :ds.get('PixelRepresentation'),
            })
        
        # TODO: Convert to NIfTI
        volm_np = np.stack(volm, axis=-1)
        affine = np.eye(4)
        nifti_img = nib.Nifti1Image(volm_np, affine)
        
        save_dirpath = Path(self.save_dirpath)
        save_dirpath.mkdir(parents=True, exist_ok=True)
        nifti_filepath = save_dirpath / datetime.datetime.now().strftime("converted_volume_%Y-%m-%d_%H-%M-%S.nii")
        nib.save(nifti_img, nifti_filepath)

        path_to_nifti_file = nifti_filepath
        return path_to_nifti_file, meta_list

# %%
# sample 1
series_path = Path("3000566.000000-NA-03192")
paths_list = list(series_path.glob("*.dcm"))
path_to_nifti_file, meta_list = DICOMToNIfTI(paths_list).convert()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1945125074.py in <cell line: 0>()
#       2 series_path = Path("3000566.000000-NA-03192")
#       3 paths_list = list(series_path.glob("*.dcm"))
# ----> 4 path_to_nifti_file, meta_list = DICOMToNIfTI(paths_list).convert()
#
# /tmp/ipython-input-449736269.py in convert(self)
#      44
#      45         # TODO: Convert to NIfTI
# ---> 46         volm_np = np.stack(volm, axis=-1)
#      47         affine = np.eye(4)
#      48         nifti_img = nib.Nifti1Image(volm_np, affine)
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/shape_base.py in stack(arrays, axis, out, dtype, casting)
#     442     arrays = [asanyarray(arr) for arr in arrays]
#     443     if not arrays:
# --> 444         raise ValueError('need at least one array to stack')
#     445
#     446     shapes = {arr.shape for arr in arrays}
#
# ValueError: need at least one array to stack

# %%
# sample 2 - series with max no of slices
import SimpleITK as sitk

def get_best_series_path(dicom_dir):
    def count_slices(series_file_names):
        return len(series_file_names)
    
    series_IDs = sitk.ImageSeriesReader.GetGDCMSeriesIDs(dicom_dir)

    max_slices = 0
    best_series_file_names = []

    for series_ID in series_IDs:
        series_file_names = sitk.ImageSeriesReader.GetGDCMSeriesFileNames(dicom_dir, series_ID)
        num_slices = count_slices(series_file_names)
        #print(f"{series_ID} : {num_slices} ")
        if num_slices > max_slices:
            max_slices = num_slices
            best_series_file_names = series_file_names

    return best_series_file_names

series_path = 'D:\\manentia_task\\JANAK_P'
paths_list = get_best_series_path(series_path)
path_to_nifti_file, meta_list = DICOMToNIfTI(paths_list).convert()
# Out:
# ds.get('ImagePositionPatient')[-1] = '1269.0'
# ds.get('ImagePositionPatient')[-1] = '1269.5'
# ds.get('ImagePositionPatient')[-1] = '1270.0'
# ds.get('ImagePositionPatient')[-1] = '1270.5'
# ds.get('ImagePositionPatient')[-1] = '1271.0'
# ds.get('ImagePositionPatient')[-1] = '1271.5'
# ds.get('ImagePositionPatient')[-1] = '1272.0'
# ds.get('ImagePositionPatient')[-1] = '1272.5'
# ds.get('ImagePositionPatient')[-1] = '1273.0'
# ds.get('ImagePositionPatient')[-1] = '1273.5'
# ds.get('ImagePositionPatient')[-1] = '1274.0'
# ds.get('ImagePositionPatient')[-1] = '1274.5'
# ds.get('ImagePositionPatient')[-1] = '1275.0'
# ds.get('ImagePositionPatient')[-1] = '1275.5'
# ds.get('ImagePositionPatient')[-1] = '1276.0'
# ds.get('ImagePositionPatient')[-1] = '1276.5'
# ds.get('ImagePositionPatient')[-1] = '1277.0'
# ds.get('ImagePositionPatient')[-1] = '1277.5'
# ds.get('ImagePositionPatient')[-1] = '1278.0'
# ds.get('ImagePositionPatient')[-1] = '1278.5'
# ds.get('ImagePositionPatient')[-1] = '1279.0'
# ds.get('ImagePositionPatient')[-1] = '1279.5'
# ds.get('ImagePositionPatient')[-1] = '1280.0'
# ds.get('ImagePositionPatient')[-1] = '1280.5'
# ds.get('ImagePositionPatient')[-1] = '1281.0'
# ds.get('ImagePositionPatient')[-1] = '1281.5'
# ds.get('ImagePositionPatient')[-1] = '1282.0'
# ds.get('ImagePositionPatient')[-1] = '1282.5'
# ds.get('ImagePositionPatient')[-1] = '1283.0'
# ds.get('ImagePositionPatient')[-1] = '1283.5'
# ds.get('ImagePositionPatient')[-1] = '1284.0'
# ds.get('ImagePositionPatient')[-1] = '1284.5'
# ds.get('ImagePositionPatient')[-1] = '1285.0'
# ds.get('ImagePositionPatient')[-1] = '1285.5'
# ds.get('ImagePositionPatient')[-1] = '1286.0'
# ds.get('ImagePositionPatient')[-1] = '1286.5'
# ds.get('ImagePositionPatient')[-1] = '1287.0'
# ds.get('ImagePositionPatient')[-1] = '1287.5'
# ds.get('ImagePositionPatient')[-1] = '1288.0'
# ds.get('ImagePositionPatient')[-1] = '1288.5'
# ds.get('ImagePositionPatient')[-1] = '1289.0'
# ds.get('ImagePositionPatient')[-1] = '1289.5'
# ds.get('ImagePositionPatient')[-1] = '1290.0'
# ds.get('ImagePositionPatient')[-1] = '1290.5'
# ds.get('ImagePositionPatient')[-1] = '1291.0'
# ds.get('ImagePositionPatient')[-1] = '1291.5'
# ds.get('ImagePositionPatient')[-1] = '1292.0'
# ds.get('ImagePositionPatient')[-1] = '1292.5'
# ds.get('ImagePositionPatient')[-1] = '1293.0'
# ds.get('ImagePositionPatient')[-1] = '1293.5'
# ds.get('ImagePositionPatient')[-1] = '1294.0'
# ds.get('ImagePositionPatient')[-1] = '1294.5'
# ds.get('ImagePositionPatient')[-1] = '1295.0'
# ds.get('ImagePositionPatient')[-1] = '1295.5'
# ds.get('ImagePositionPatient')[-1] = '1296.0'
# ds.get('ImagePositionPatient')[-1] = '1296.5'
# ds.get('ImagePositionPatient')[-1] = '1297.0'
# ds.get('ImagePositionPatient')[-1] = '1297.5'
# ds.get('ImagePositionPatient')[-1] = '1298.0'
# ds.get('ImagePositionPatient')[-1] = '1298.5'
# ds.get('ImagePositionPatient')[-1] = '1299.0'
# ds.get('ImagePositionPatient')[-1] = '1299.5'
# ds.get('ImagePositionPatient')[-1] = '1300.0'
# ds.get('ImagePositionPatient')[-1] = '1300.5'
# ds.get('ImagePositionPatient')[-1] = '1301.0'
# ds.get('ImagePositionPatient')[-1] = '1301.5'
# ds.get('ImagePositionPatient')[-1] = '1302.0'
# ds.get('ImagePositionPatient')[-1] = '1302.5'
# ds.get('ImagePositionPatient')[-1] = '1303.0'
# ds.get('ImagePositionPatient')[-1] = '1303.5'
# ds.get('ImagePositionPatient')[-1] = '1304.0'
# ds.get('ImagePositionPatient')[-1] = '1304.5'
# ds.get('ImagePositionPatient')[-1] = '1305.0'
# ds.get('ImagePositionPatient')[-1] = '1305.5'
# ds.get('ImagePositionPatient')[-1] = '1306.0'
# ds.get('ImagePositionPatient')[-1] = '1306.5'
# ds.get('ImagePositionPatient')[-1] = '1307.0'
# ds.get('ImagePositionPatient')[-1] = '1307.5'
# ds.get('ImagePositionPatient')[-1] = '1308.0'
# ds.get('ImagePositionPatient')[-1] = '1308.5'
# ds.get('ImagePositionPatient')[-1] = '1309.0'
# ds.get('ImagePositionPatient')[-1] = '1309.5'
# ds.get('ImagePositionPatient')[-1] = '1310.0'
# ds.get('ImagePositionPatient')[-1] = '1310.5'
# ds.get('ImagePositionPatient')[-1] = '1311.0'
# ds.get('ImagePositionPatient')[-1] = '1311.5'
# ds.get('ImagePositionPatient')[-1] = '1312.0'
# ds.get('ImagePositionPatient')[-1] = '1312.5'
# ds.get('ImagePositionPatient')[-1] = '1313.0'
# ds.get('ImagePositionPatient')[-1] = '1313.5'
# ds.get('ImagePositionPatient')[-1] = '1314.0'
# ds.get('ImagePositionPatient')[-1] = '1314.5'
# ds.get('ImagePositionPatient')[-1] = '1315.0'
# ds.get('ImagePositionPatient')[-1] = '1315.5'
# ds.get('ImagePositionPatient')[-1] = '1316.0'
# ds.get('ImagePositionPatient')[-1] = '1316.5'
# ds.get('ImagePositionPatient')[-1] = '1317.0'
# ds.get('ImagePositionPatient')[-1] = '1317.5'
# ds.get('ImagePositionPatient')[-1] = '1318.0'
# ds.get('ImagePositionPatient')[-1] = '1318.5'
# ds.get('ImagePositionPatient')[-1] = '1319.0'
# ds.get('ImagePositionPatient')[-1] = '1319.5'
# ds.get('ImagePositionPatient')[-1] = '1320.0'
# ds.get('ImagePositionPatient')[-1] = '1320.5'
# ds.get('ImagePositionPatient')[-1] = '1321.0'
# ds.get('ImagePositionPatient')[-1] = '1321.5'
# ds.get('ImagePositionPatient')[-1] = '1322.0'
# ds.get('ImagePositionPatient')[-1] = '1322.5'
# ds.get('ImagePositionPatient')[-1] = '1323.0'
# ds.get('ImagePositionPatient')[-1] = '1323.5'
# ds.get('ImagePositionPatient')[-1] = '1324.0'
# ds.get('ImagePositionPatient')[-1] = '1324.5'
# ds.get('ImagePositionPatient')[-1] = '1325.0'
# ds.get('ImagePositionPatient')[-1] = '1325.5'
# ds.get('ImagePositionPatient')[-1] = '1326.0'
# ds.get('ImagePositionPatient')[-1] = '1326.5'
# ds.get('ImagePositionPatient')[-1] = '1327.0'
# ds.get('ImagePositionPatient')[-1] = '1327.5'
# ds.get('ImagePositionPatient')[-1] = '1328.0'
# ds.get('ImagePositionPatient')[-1] = '1328.5'
# ds.get('ImagePositionPatient')[-1] = '1329.0'
# ds.get('ImagePositionPatient')[-1] = '1329.5'
# ds.get('ImagePositionPatient')[-1] = '1330.0'
# ds.get('ImagePositionPatient')[-1] = '1330.5'
# ds.get('ImagePositionPatient')[-1] = '1331.0'
# ds.get('ImagePositionPatient')[-1] = '1331.5'
# ds.get('ImagePositionPatient')[-1] = '1332.0'
# ds.get('ImagePositionPatient')[-1] = '1332.5'
# ds.get('ImagePositionPatient')[-1] = '1333.0'
# ds.get('ImagePositionPatient')[-1] = '1333.5'
# ds.get('ImagePositionPatient')[-1] = '1334.0'
# ds.get('ImagePositionPatient')[-1] = '1334.5'
# ds.get('ImagePositionPatient')[-1] = '1335.0'
# ds.get('ImagePositionPatient')[-1] = '1335.5'
# ds.get('ImagePositionPatient')[-1] = '1336.0'
# ds.get('ImagePositionPatient')[-1] = '1336.5'
# ds.get('ImagePositionPatient')[-1] = '1337.0'
# ds.get('ImagePositionPatient')[-1] = '1337.5'
# ds.get('ImagePositionPatient')[-1] = '1338.0'
# ds.get('ImagePositionPatient')[-1] = '1338.5'
# ds.get('ImagePositionPatient')[-1] = '1339.0'
# ds.get('ImagePositionPatient')[-1] = '1339.5'
# ds.get('ImagePositionPatient')[-1] = '1340.0'
# ds.get('ImagePositionPatient')[-1] = '1340.5'
# ds.get('ImagePositionPatient')[-1] = '1341.0'
# ds.get('ImagePositionPatient')[-1] = '1341.5'
# ds.get('ImagePositionPatient')[-1] = '1342.0'
# ds.get('ImagePositionPatient')[-1] = '1342.5'
# ds.get('ImagePositionPatient')[-1] = '1343.0'
# ds.get('ImagePositionPatient')[-1] = '1343.5'
# ds.get('ImagePositionPatient')[-1] = '1344.0'
# ds.get('ImagePositionPatient')[-1] = '1344.5'
# ds.get('ImagePositionPatient')[-1] = '1345.0'
# ds.get('ImagePositionPatient')[-1] = '1345.5'
# ds.get('ImagePositionPatient')[-1] = '1346.0'
# ds.get('ImagePositionPatient')[-1] = '1346.5'
# ds.get('ImagePositionPatient')[-1] = '1347.0'
# ds.get('ImagePositionPatient')[-1] = '1347.5'
# ds.get('ImagePositionPatient')[-1] = '1348.0'
# ds.get('ImagePositionPatient')[-1] = '1348.5'
# ds.get('ImagePositionPatient')[-1] = '1349.0'
# ds.get('ImagePositionPatient')[-1] = '1349.5'
# ds.get('ImagePositionPatient')[-1] = '1350.0'
# ds.get('ImagePositionPatient')[-1] = '1350.5'
# ds.get('ImagePositionPatient')[-1] = '1351.0'
# ds.get('ImagePositionPatient')[-1] = '1351.5'
# ds.get('ImagePositionPatient')[-1] = '1352.0'
# ds.get('ImagePositionPatient')[-1] = '1352.5'
# ds.get('ImagePositionPatient')[-1] = '1353.0'
# ds.get('ImagePositionPatient')[-1] = '1353.5'
# ds.get('ImagePositionPatient')[-1] = '1354.0'
# ds.get('ImagePositionPatient')[-1] = '1354.5'
# ds.get('ImagePositionPatient')[-1] = '1355.0'
# ds.get('ImagePositionPatient')[-1] = '1355.5'
# ds.get('ImagePositionPatient')[-1] = '1356.0'
# ds.get('ImagePositionPatient')[-1] = '1356.5'
# ds.get('ImagePositionPatient')[-1] = '1357.0'
# ds.get('ImagePositionPatient')[-1] = '1357.5'
# ds.get('ImagePositionPatient')[-1] = '1358.0'
# ds.get('ImagePositionPatient')[-1] = '1358.5'
# ds.get('ImagePositionPatient')[-1] = '1359.0'
# ds.get('ImagePositionPatient')[-1] = '1359.5'
# ds.get('ImagePositionPatient')[-1] = '1360.0'
# ds.get('ImagePositionPatient')[-1] = '1360.5'
# ds.get('ImagePositionPatient')[-1] = '1361.0'
# ds.get('ImagePositionPatient')[-1] = '1361.5'
# ds.get('ImagePositionPatient')[-1] = '1362.0'
# ds.get('ImagePositionPatient')[-1] = '1362.5'
# ds.get('ImagePositionPatient')[-1] = '1363.0'
# ds.get('ImagePositionPatient')[-1] = '1363.5'
# ds.get('ImagePositionPatient')[-1] = '1364.0'
# ds.get('ImagePositionPatient')[-1] = '1364.5'
# ds.get('ImagePositionPatient')[-1] = '1365.0'
# ds.get('ImagePositionPatient')[-1] = '1365.5'
# ds.get('ImagePositionPatient')[-1] = '1366.0'
# ds.get('ImagePositionPatient')[-1] = '1366.5'
# ds.get('ImagePositionPatient')[-1] = '1367.0'
# ds.get('ImagePositionPatient')[-1] = '1367.5'
# ds.get('ImagePositionPatient')[-1] = '1368.0'
# ds.get('ImagePositionPatient')[-1] = '1368.5'
# ds.get('ImagePositionPatient')[-1] = '1369.0'
# ds.get('ImagePositionPatient')[-1] = '1369.5'
# ds.get('ImagePositionPatient')[-1] = '1370.0'
# ds.get('ImagePositionPatient')[-1] = '1370.5'
# ds.get('ImagePositionPatient')[-1] = '1371.0'
# ds.get('ImagePositionPatient')[-1] = '1371.5'
# ds.get('ImagePositionPatient')[-1] = '1372.0'
# ds.get('ImagePositionPatient')[-1] = '1372.5'
# ds.get('ImagePositionPatient')[-1] = '1373.0'
# ds.get('ImagePositionPatient')[-1] = '1373.5'
# ds.get('ImagePositionPatient')[-1] = '1374.0'
# ds.get('ImagePositionPatient')[-1] = '1374.5'
# ds.get('ImagePositionPatient')[-1] = '1375.0'
# ds.get('ImagePositionPatient')[-1] = '1375.5'
# ds.get('ImagePositionPatient')[-1] = '1376.0'
# ds.get('ImagePositionPatient')[-1] = '1376.5'
# ds.get('ImagePositionPatient')[-1] = '1377.0'
# ds.get('ImagePositionPatient')[-1] = '1377.5'
# ds.get('ImagePositionPatient')[-1] = '1378.0'
# ds.get('ImagePositionPatient')[-1] = '1378.5'
# ds.get('ImagePositionPatient')[-1] = '1379.0'
# ds.get('ImagePositionPatient')[-1] = '1379.5'
# ds.get('ImagePositionPatient')[-1] = '1380.0'
# ds.get('ImagePositionPatient')[-1] = '1380.5'
# ds.get('ImagePositionPatient')[-1] = '1381.0'
# ds.get('ImagePositionPatient')[-1] = '1381.5'
# ds.get('ImagePositionPatient')[-1] = '1382.0'
# ds.get('ImagePositionPatient')[-1] = '1382.5'
# ds.get('ImagePositionPatient')[-1] = '1383.0'
# ds.get('ImagePositionPatient')[-1] = '1383.5'
# ds.get('ImagePositionPatient')[-1] = '1384.0'
# ds.get('ImagePositionPatient')[-1] = '1384.5'
# ds.get('ImagePositionPatient')[-1] = '1385.0'
# ds.get('ImagePositionPatient')[-1] = '1385.5'
# ds.get('ImagePositionPatient')[-1] = '1386.0'
# ds.get('ImagePositionPatient')[-1] = '1386.5'
# ds.get('ImagePositionPatient')[-1] = '1387.0'
# ds.get('ImagePositionPatient')[-1] = '1387.5'
# ds.get('ImagePositionPatient')[-1] = '1388.0'
# ds.get('ImagePositionPatient')[-1] = '1388.5'
# ds.get('ImagePositionPatient')[-1] = '1389.0'
# ds.get('ImagePositionPatient')[-1] = '1389.5'
# ds.get('ImagePositionPatient')[-1] = '1390.0'
# ds.get('ImagePositionPatient')[-1] = '1390.5'
# ds.get('ImagePositionPatient')[-1] = '1391.0'
# ds.get('ImagePositionPatient')[-1] = '1391.5'
# ds.get('ImagePositionPatient')[-1] = '1392.0'
# ds.get('ImagePositionPatient')[-1] = '1392.5'
# ds.get('ImagePositionPatient')[-1] = '1393.0'
# ds.get('ImagePositionPatient')[-1] = '1393.5'
# ds.get('ImagePositionPatient')[-1] = '1394.0'
# ds.get('ImagePositionPatient')[-1] = '1394.5'
# ds.get('ImagePositionPatient')[-1] = '1395.0'
# ds.get('ImagePositionPatient')[-1] = '1395.5'
# ds.get('ImagePositionPatient')[-1] = '1396.0'
# ds.get('ImagePositionPatient')[-1] = '1396.5'
# ds.get('ImagePositionPatient')[-1] = '1397.0'
# ds.get('ImagePositionPatient')[-1] = '1397.5'
# ds.get('ImagePositionPatient')[-1] = '1398.0'
# ds.get('ImagePositionPatient')[-1] = '1398.5'
# ds.get('ImagePositionPatient')[-1] = '1399.0'
# ds.get('ImagePositionPatient')[-1] = '1399.5'
# ds.get('ImagePositionPatient')[-1] = '1400.0'
# ds.get('ImagePositionPatient')[-1] = '1400.5'
# ds.get('ImagePositionPatient')[-1] = '1401.0'
# ds.get('ImagePositionPatient')[-1] = '1401.5'
# ds.get('ImagePositionPatient')[-1] = '1402.0'
# ds.get('ImagePositionPatient')[-1] = '1402.5'
# ds.get('ImagePositionPatient')[-1] = '1403.0'
# ds.get('ImagePositionPatient')[-1] = '1403.5'
# ds.get('ImagePositionPatient')[-1] = '1404.0'
# ds.get('ImagePositionPatient')[-1] = '1404.5'
# ds.get('ImagePositionPatient')[-1] = '1405.0'
# ds.get('ImagePositionPatient')[-1] = '1405.5'
# ds.get('ImagePositionPatient')[-1] = '1406.0'
# ds.get('ImagePositionPatient')[-1] = '1406.5'
# ds.get('ImagePositionPatient')[-1] = '1407.0'
# ds.get('ImagePositionPatient')[-1] = '1407.5'
# ds.get('ImagePositionPatient')[-1] = '1408.0'
# ds.get('ImagePositionPatient')[-1] = '1408.5'
# ds.get('ImagePositionPatient')[-1] = '1409.0'
# ds.get('ImagePositionPatient')[-1] = '1409.5'
# ds.get('ImagePositionPatient')[-1] = '1410.0'
# ds.get('ImagePositionPatient')[-1] = '1410.5'
# ds.get('ImagePositionPatient')[-1] = '1411.0'
# ds.get('ImagePositionPatient')[-1] = '1411.5'
# ds.get('ImagePositionPatient')[-1] = '1412.0'
# ds.get('ImagePositionPatient')[-1] = '1412.5'
# ds.get('ImagePositionPatient')[-1] = '1413.0'
# ds.get('ImagePositionPatient')[-1] = '1413.5'
# ds.get('ImagePositionPatient')[-1] = '1414.0'
# ds.get('ImagePositionPatient')[-1] = '1414.5'
# ds.get('ImagePositionPatient')[-1] = '1415.0'
# ds.get('ImagePositionPatient')[-1] = '1415.5'
# ds.get('ImagePositionPatient')[-1] = '1416.0'
# ds.get('ImagePositionPatient')[-1] = '1416.5'
# ds.get('ImagePositionPatient')[-1] = '1417.0'
# ds.get('ImagePositionPatient')[-1] = '1417.5'
# ds.get('ImagePositionPatient')[-1] = '1418.0'
# ds.get('ImagePositionPatient')[-1] = '1418.5'
# ds.get('ImagePositionPatient')[-1] = '1419.0'
# ds.get('ImagePositionPatient')[-1] = '1419.5'
# ds.get('ImagePositionPatient')[-1] = '1420.0'
# ds.get('ImagePositionPatient')[-1] = '1420.5'
# ds.get('ImagePositionPatient')[-1] = '1421.0'
# ds.get('ImagePositionPatient')[-1] = '1421.5'
# ds.get('ImagePositionPatient')[-1] = '1422.0'
# ds.get('ImagePositionPatient')[-1] = '1422.5'
# ds.get('ImagePositionPatient')[-1] = '1423.0'
# ds.get('ImagePositionPatient')[-1] = '1423.5'
# ds.get('ImagePositionPatient')[-1] = '1424.0'
# ds.get('ImagePositionPatient')[-1] = '1424.5'
# ds.get('ImagePositionPatient')[-1] = '1425.0'
# ds.get('ImagePositionPatient')[-1] = '1425.5'
# ds.get('ImagePositionPatient')[-1] = '1426.0'
# ds.get('ImagePositionPatient')[-1] = '1426.5'
# ds.get('ImagePositionPatient')[-1] = '1427.0'
# ds.get('ImagePositionPatient')[-1] = '1427.5'
# ds.get('ImagePositionPatient')[-1] = '1428.0'
# ds.get('ImagePositionPatient')[-1] = '1428.5'
# ds.get('ImagePositionPatient')[-1] = '1429.0'
# ds.get('ImagePositionPatient')[-1] = '1429.5'
# ds.get('ImagePositionPatient')[-1] = '1430.0'
# ds.get('ImagePositionPatient')[-1] = '1430.5'
# ds.get('ImagePositionPatient')[-1] = '1431.0'
# ds.get('ImagePositionPatient')[-1] = '1431.5'
# ds.get('ImagePositionPatient')[-1] = '1432.0'
# ds.get('ImagePositionPatient')[-1] = '1432.5'
# ds.get('ImagePositionPatient')[-1] = '1433.0'
# ds.get('ImagePositionPatient')[-1] = '1433.5'
# ds.get('ImagePositionPatient')[-1] = '1434.0'
# ds.get('ImagePositionPatient')[-1] = '1434.5'
# ds.get('ImagePositionPatient')[-1] = '1435.0'
# ds.get('ImagePositionPatient')[-1] = '1435.5'
# ds.get('ImagePositionPatient')[-1] = '1436.0'
# ds.get('ImagePositionPatient')[-1] = '1436.5'
# ds.get('ImagePositionPatient')[-1] = '1437.0'
# ds.get('ImagePositionPatient')[-1] = '1437.5'
# ds.get('ImagePositionPatient')[-1] = '1438.0'
# ds.get('ImagePositionPatient')[-1] = '1438.5'
# ds.get('ImagePositionPatient')[-1] = '1439.0'
# ds.get('ImagePositionPatient')[-1] = '1439.5'
# ds.get('ImagePositionPatient')[-1] = '1440.0'
# ds.get('ImagePositionPatient')[-1] = '1440.5'
# ds.get('ImagePositionPatient')[-1] = '1441.0'
# ds.get('ImagePositionPatient')[-1] = '1441.5'
# ds.get('ImagePositionPatient')[-1] = '1442.0'
# ds.get('ImagePositionPatient')[-1] = '1442.5'
# ds.get('ImagePositionPatient')[-1] = '1443.0'
# ds.get('ImagePositionPatient')[-1] = '1443.5'
# ds.get('ImagePositionPatient')[-1] = '1444.0'
# ds.get('ImagePositionPatient')[-1] = '1444.5'
# ds.get('ImagePositionPatient')[-1] = '1445.0'
# ds.get('ImagePositionPatient')[-1] = '1445.5'
# ds.get('ImagePositionPatient')[-1] = '1446.0'
# ds.get('ImagePositionPatient')[-1] = '1446.5'
# ds.get('ImagePositionPatient')[-1] = '1447.0'
# ds.get('ImagePositionPatient')[-1] = '1447.5'
# ds.get('ImagePositionPatient')[-1] = '1448.0'
# ds.get('ImagePositionPatient')[-1] = '1448.5'
# ds.get('ImagePositionPatient')[-1] = '1449.0'
# ds.get('ImagePositionPatient')[-1] = '1449.5'
# ds.get('ImagePositionPatient')[-1] = '1450.0'
# ds.get('ImagePositionPatient')[-1] = '1450.5'
# ds.get('ImagePositionPatient')[-1] = '1451.0'
# ds.get('ImagePositionPatient')[-1] = '1451.5'
# ds.get('ImagePositionPatient')[-1] = '1452.0'
# ds.get('ImagePositionPatient')[-1] = '1452.5'
# ds.get('ImagePositionPatient')[-1] = '1453.0'
# ds.get('ImagePositionPatient')[-1] = '1453.5'
# ds.get('ImagePositionPatient')[-1] = '1454.0'
# ds.get('ImagePositionPatient')[-1] = '1454.5'
# ds.get('ImagePositionPatient')[-1] = '1455.0'
# ds.get('ImagePositionPatient')[-1] = '1455.5'
# ds.get('ImagePositionPatient')[-1] = '1456.0'
# ds.get('ImagePositionPatient')[-1] = '1456.5'
# ds.get('ImagePositionPatient')[-1] = '1457.0'
# ds.get('ImagePositionPatient')[-1] = '1457.5'
# ds.get('ImagePositionPatient')[-1] = '1458.0'
# ds.get('ImagePositionPatient')[-1] = '1458.5'
# ds.get('ImagePositionPatient')[-1] = '1459.0'
# ds.get('ImagePositionPatient')[-1] = '1459.5'
# ds.get('ImagePositionPatient')[-1] = '1460.0'
# ds.get('ImagePositionPatient')[-1] = '1460.5'
# ds.get('ImagePositionPatient')[-1] = '1461.0'
# ds.get('ImagePositionPatient')[-1] = '1461.5'
# ds.get('ImagePositionPatient')[-1] = '1462.0'
# ds.get('ImagePositionPatient')[-1] = '1462.5'
# ds.get('ImagePositionPatient')[-1] = '1463.0'
# ds.get('ImagePositionPatient')[-1] = '1463.5'
# ds.get('ImagePositionPatient')[-1] = '1464.0'
# ds.get('ImagePositionPatient')[-1] = '1464.5'
# ds.get('ImagePositionPatient')[-1] = '1465.0'
# ds.get('ImagePositionPatient')[-1] = '1465.5'
# ds.get('ImagePositionPatient')[-1] = '1466.0'
# ds.get('ImagePositionPatient')[-1] = '1466.5'
# ds.get('ImagePositionPatient')[-1] = '1467.0'
# ds.get('ImagePositionPatient')[-1] = '1467.5'
# ds.get('ImagePositionPatient')[-1] = '1468.0'
# ds.get('ImagePositionPatient')[-1] = '1468.5'
# ds.get('ImagePositionPatient')[-1] = '1469.0'
# ds.get('ImagePositionPatient')[-1] = '1469.5'
# ds.get('ImagePositionPatient')[-1] = '1470.0'
# ds.get('ImagePositionPatient')[-1] = '1470.5'
# ds.get('ImagePositionPatient')[-1] = '1471.0'
# ds.get('ImagePositionPatient')[-1] = '1471.5'
# ds.get('ImagePositionPatient')[-1] = '1472.0'
# ds.get('ImagePositionPatient')[-1] = '1472.5'
# ds.get('ImagePositionPatient')[-1] = '1473.0'
# ds.get('ImagePositionPatient')[-1] = '1473.5'
# ds.get('ImagePositionPatient')[-1] = '1474.0'
# ds.get('ImagePositionPatient')[-1] = '1474.5'
# ds.get('ImagePositionPatient')[-1] = '1475.0'
# ds.get('ImagePositionPatient')[-1] = '1475.5'
# ds.get('ImagePositionPatient')[-1] = '1476.0'
# ds.get('ImagePositionPatient')[-1] = '1476.5'
# ds.get('ImagePositionPatient')[-1] = '1477.0'
# ds.get('ImagePositionPatient')[-1] = '1477.5'
# ds.get('ImagePositionPatient')[-1] = '1478.0'
# ds.get('ImagePositionPatient')[-1] = '1478.5'
# ds.get('ImagePositionPatient')[-1] = '1479.0'
# ds.get('ImagePositionPatient')[-1] = '1479.5'
# ds.get('ImagePositionPatient')[-1] = '1480.0'
# ds.get('ImagePositionPatient')[-1] = '1480.5'
# ds.get('ImagePositionPatient')[-1] = '1481.0'
# ds.get('ImagePositionPatient')[-1] = '1481.5'
# ds.get('ImagePositionPatient')[-1] = '1482.0'
# ds.get('ImagePositionPatient')[-1] = '1482.5'
# ds.get('ImagePositionPatient')[-1] = '1483.0'
# ds.get('ImagePositionPatient')[-1] = '1483.5'
# ds.get('ImagePositionPatient')[-1] = '1484.0'
# ds.get('ImagePositionPatient')[-1] = '1484.5'
# ds.get('ImagePositionPatient')[-1] = '1485.0'
# ds.get('ImagePositionPatient')[-1] = '1485.5'
# ds.get('ImagePositionPatient')[-1] = '1486.0'
# ds.get('ImagePositionPatient')[-1] = '1486.5'
# ds.get('ImagePositionPatient')[-1] = '1487.0'
# ds.get('ImagePositionPatient')[-1] = '1487.5'
# ds.get('ImagePositionPatient')[-1] = '1488.0'
# ds.get('ImagePositionPatient')[-1] = '1488.5'
# ds.get('ImagePositionPatient')[-1] = '1489.0'
# ds.get('ImagePositionPatient')[-1] = '1489.5'
# ds.get('ImagePositionPatient')[-1] = '1490.0'
# ds.get('ImagePositionPatient')[-1] = '1490.5'
# ds.get('ImagePositionPatient')[-1] = '1491.0'
# ds.get('ImagePositionPatient')[-1] = '1491.5'
# ds.get('ImagePositionPatient')[-1] = '1492.0'
# ds.get('ImagePositionPatient')[-1] = '1492.5'
# ds.get('ImagePositionPatient')[-1] = '1493.0'
# ds.get('ImagePositionPatient')[-1] = '1493.5'
# ds.get('ImagePositionPatient')[-1] = '1494.0'
# ds.get('ImagePositionPatient')[-1] = '1494.5'
# ds.get('ImagePositionPatient')[-1] = '1495.0'
# ds.get('ImagePositionPatient')[-1] = '1495.5'
# ds.get('ImagePositionPatient')[-1] = '1496.0'
# ds.get('ImagePositionPatient')[-1] = '1496.5'
# ds.get('ImagePositionPatient')[-1] = '1497.0'
# ds.get('ImagePositionPatient')[-1] = '1497.5'
# ds.get('ImagePositionPatient')[-1] = '1498.0'
# ds.get('ImagePositionPatient')[-1] = '1498.5'
# ds.get('ImagePositionPatient')[-1] = '1499.0'
# ds.get('ImagePositionPatient')[-1] = '1499.5'
# ds.get('ImagePositionPatient')[-1] = '1500.0'
# ds.get('ImagePositionPatient')[-1] = '1500.5'
# ds.get('ImagePositionPatient')[-1] = '1501.0'
# ds.get('ImagePositionPatient')[-1] = '1501.5'
# ds.get('ImagePositionPatient')[-1] = '1502.0'
# ds.get('ImagePositionPatient')[-1] = '1502.5'
# ds.get('ImagePositionPatient')[-1] = '1503.0'
# ds.get('ImagePositionPatient')[-1] = '1503.5'
# ds.get('ImagePositionPatient')[-1] = '1504.0'
# ds.get('ImagePositionPatient')[-1] = '1504.5'
# ds.get('ImagePositionPatient')[-1] = '1505.0'
# ds.get('ImagePositionPatient')[-1] = '1505.5'
# ds.get('ImagePositionPatient')[-1] = '1506.0'
# ds.get('ImagePositionPatient')[-1] = '1506.5'
# ds.get('ImagePositionPatient')[-1] = '1507.0'
# ds.get('ImagePositionPatient')[-1] = '1507.5'
# ds.get('ImagePositionPatient')[-1] = '1508.0'
# ds.get('ImagePositionPatient')[-1] = '1508.5'
# ds.get('ImagePositionPatient')[-1] = '1509.0'
# ds.get('ImagePositionPatient')[-1] = '1509.5'
# ds.get('ImagePositionPatient')[-1] = '1510.0'
# ds.get('ImagePositionPatient')[-1] = '1510.5'
# ds.get('ImagePositionPatient')[-1] = '1511.0'
# ds.get('ImagePositionPatient')[-1] = '1511.5'
# ds.get('ImagePositionPatient')[-1] = '1512.0'
# ds.get('ImagePositionPatient')[-1] = '1512.5'
# ds.get('ImagePositionPatient')[-1] = '1513.0'
# ds.get('ImagePositionPatient')[-1] = '1513.5'
# ds.get('ImagePositionPatient')[-1] = '1514.0'
# ds.get('ImagePositionPatient')[-1] = '1514.5'
# ds.get('ImagePositionPatient')[-1] = '1515.0'
# ds.get('ImagePositionPatient')[-1] = '1515.5'
# ds.get('ImagePositionPatient')[-1] = '1516.0'
# ds.get('ImagePositionPatient')[-1] = '1516.5'
# ds.get('ImagePositionPatient')[-1] = '1517.0'
# ds.get('ImagePositionPatient')[-1] = '1517.5'
# ds.get('ImagePositionPatient')[-1] = '1518.0'
# ds.get('ImagePositionPatient')[-1] = '1518.5'
# ds.get('ImagePositionPatient')[-1] = '1519.0'
# ds.get('ImagePositionPatient')[-1] = '1519.5'
# ds.get('ImagePositionPatient')[-1] = '1520.0'
# ds.get('ImagePositionPatient')[-1] = '1520.5'
# ds.get('ImagePositionPatient')[-1] = '1521.0'
# ds.get('ImagePositionPatient')[-1] = '1521.5'
# ds.get('ImagePositionPatient')[-1] = '1522.0'
# ds.get('ImagePositionPatient')[-1] = '1522.5'
# ds.get('ImagePositionPatient')[-1] = '1523.0'
# ds.get('ImagePositionPatient')[-1] = '1523.5'
# ds.get('ImagePositionPatient')[-1] = '1524.0'
# ds.get('ImagePositionPatient')[-1] = '1524.5'
# ds.get('ImagePositionPatient')[-1] = '1525.0'
# ds.get('ImagePositionPatient')[-1] = '1525.5'
# ds.get('ImagePositionPatient')[-1] = '1526.0'
# ds.get('ImagePositionPatient')[-1] = '1526.5'
# ds.get('ImagePositionPatient')[-1] = '1527.0'
# ds.get('ImagePositionPatient')[-1] = '1527.5'
# ds.get('ImagePositionPatient')[-1] = '1528.0'
# ds.get('ImagePositionPatient')[-1] = '1528.5'
# ds.get('ImagePositionPatient')[-1] = '1529.0'
# ds.get('ImagePositionPatient')[-1] = '1529.5'
# ds.get('ImagePositionPatient')[-1] = '1530.0'
# ds.get('ImagePositionPatient')[-1] = '1530.5'
# ds.get('ImagePositionPatient')[-1] = '1531.0'
# ds.get('ImagePositionPatient')[-1] = '1531.5'
# ds.get('ImagePositionPatient')[-1] = '1532.0'
# ds.get('ImagePositionPatient')[-1] = '1532.5'
# ds.get('ImagePositionPatient')[-1] = '1533.0'
# ds.get('ImagePositionPatient')[-1] = '1533.5'
# ds.get('ImagePositionPatient')[-1] = '1534.0'
# ds.get('ImagePositionPatient')[-1] = '1534.5'
# ds.get('ImagePositionPatient')[-1] = '1535.0'
# ds.get('ImagePositionPatient')[-1] = '1535.5'
# ds.get('ImagePositionPatient')[-1] = '1536.0'
# ds.get('ImagePositionPatient')[-1] = '1536.5'
# ds.get('ImagePositionPatient')[-1] = '1537.0'
# ds.get('ImagePositionPatient')[-1] = '1537.5'
# ds.get('ImagePositionPatient')[-1] = '1538.0'
# ds.get('ImagePositionPatient')[-1] = '1538.5'
# ds.get('ImagePositionPatient')[-1] = '1539.0'
# ds.get('ImagePositionPatient')[-1] = '1539.5'
# ds.get('ImagePositionPatient')[-1] = '1540.0'
# ds.get('ImagePositionPatient')[-1] = '1540.5'
# ds.get('ImagePositionPatient')[-1] = '1541.0'
# ds.get('ImagePositionPatient')[-1] = '1541.5'
# ds.get('ImagePositionPatient')[-1] = '1542.0'
# ds.get('ImagePositionPatient')[-1] = '1542.5'
# ds.get('ImagePositionPatient')[-1] = '1543.0'
# ds.get('ImagePositionPatient')[-1] = '1543.5'
# ds.get('ImagePositionPatient')[-1] = '1544.0'
# ds.get('ImagePositionPatient')[-1] = '1544.5'
# ds.get('ImagePositionPatient')[-1] = '1545.0'
# ds.get('ImagePositionPatient')[-1] = '1545.5'
# ds.get('ImagePositionPatient')[-1] = '1546.0'
# ds.get('ImagePositionPatient')[-1] = '1546.5'
# ds.get('ImagePositionPatient')[-1] = '1547.0'
# ds.get('ImagePositionPatient')[-1] = '1547.5'
# ds.get('ImagePositionPatient')[-1] = '1548.0'
# ds.get('ImagePositionPatient')[-1] = '1548.5'
# ds.get('ImagePositionPatient')[-1] = '1549.0'
# ds.get('ImagePositionPatient')[-1] = '1549.5'
# ds.get('ImagePositionPatient')[-1] = '1550.0'
# ds.get('ImagePositionPatient')[-1] = '1550.5'
# ds.get('ImagePositionPatient')[-1] = '1551.0'
# ds.get('ImagePositionPatient')[-1] = '1551.5'
# ds.get('ImagePositionPatient')[-1] = '1552.0'
# ds.get('ImagePositionPatient')[-1] = '1552.5'
# ds.get('ImagePositionPatient')[-1] = '1553.0'
# ds.get('ImagePositionPatient')[-1] = '1553.5'
# ds.get('ImagePositionPatient')[-1] = '1554.0'
# ds.get('ImagePositionPatient')[-1] = '1554.5'
# ds.get('ImagePositionPatient')[-1] = '1555.0'
# ds.get('ImagePositionPatient')[-1] = '1555.5'
# ds.get('ImagePositionPatient')[-1] = '1556.0'
# ds.get('ImagePositionPatient')[-1] = '1556.5'
# ds.get('ImagePositionPatient')[-1] = '1557.0'
# ds.get('ImagePositionPatient')[-1] = '1557.5'
# ds.get('ImagePositionPatient')[-1] = '1558.0'
# ds.get('ImagePositionPatient')[-1] = '1558.5'
# ds.get('ImagePositionPatient')[-1] = '1559.0'
# ds.get('ImagePositionPatient')[-1] = '1559.5'
# ds.get('ImagePositionPatient')[-1] = '1560.0'
# ds.get('ImagePositionPatient')[-1] = '1560.5'
# ds.get('ImagePositionPatient')[-1] = '1561.0'
# ds.get('ImagePositionPatient')[-1] = '1561.5'
# ds.get('ImagePositionPatient')[-1] = '1562.0'
# ds.get('ImagePositionPatient')[-1] = '1562.5'
# ds.get('ImagePositionPatient')[-1] = '1563.0'
# ds.get('ImagePositionPatient')[-1] = '1563.5'
# ds.get('ImagePositionPatient')[-1] = '1564.0'
# ds.get('ImagePositionPatient')[-1] = '1564.5'
# ds.get('ImagePositionPatient')[-1] = '1565.0'
# ds.get('ImagePositionPatient')[-1] = '1565.5'
# ds.get('ImagePositionPatient')[-1] = '1566.0'
# ds.get('ImagePositionPatient')[-1] = '1566.5'
# ds.get('ImagePositionPatient')[-1] = '1567.0'
# ds.get('ImagePositionPatient')[-1] = '1567.5'
# ds.get('ImagePositionPatient')[-1] = '1568.0'
# ds.get('ImagePositionPatient')[-1] = '1568.5'
# ds.get('ImagePositionPatient')[-1] = '1569.0'
# ds.get('ImagePositionPatient')[-1] = '1569.5'
# ds.get('ImagePositionPatient')[-1] = '1570.0'
# ds.get('ImagePositionPatient')[-1] = '1570.5'
# ds.get('ImagePositionPatient')[-1] = '1571.0'
# ds.get('ImagePositionPatient')[-1] = '1571.5'
# ds.get('ImagePositionPatient')[-1] = '1572.0'
# ds.get('ImagePositionPatient')[-1] = '1572.5'
# ds.get('ImagePositionPatient')[-1] = '1573.0'
# ds.get('ImagePositionPatient')[-1] = '1573.5'
# ds.get('ImagePositionPatient')[-1] = '1574.0'
# ds.get('ImagePositionPatient')[-1] = '1574.5'
# ds.get('ImagePositionPatient')[-1] = '1575.0'
# ds.get('ImagePositionPatient')[-1] = '1575.5'
# ds.get('ImagePositionPatient')[-1] = '1576.0'
# ds.get('ImagePositionPatient')[-1] = '1576.5'
# ds.get('ImagePositionPatient')[-1] = '1577.0'
# ds.get('ImagePositionPatient')[-1] = '1577.5'
# ds.get('ImagePositionPatient')[-1] = '1578.0'
# ds.get('ImagePositionPatient')[-1] = '1578.5'
# ds.get('ImagePositionPatient')[-1] = '1579.0'
# ds.get('ImagePositionPatient')[-1] = '1579.5'
# ds.get('ImagePositionPatient')[-1] = '1580.0'
# ds.get('ImagePositionPatient')[-1] = '1580.5'
# ds.get('ImagePositionPatient')[-1] = '1581.0'
# ds.get('ImagePositionPatient')[-1] = '1581.5'
# ds.get('ImagePositionPatient')[-1] = '1582.0'
# ds.get('ImagePositionPatient')[-1] = '1582.5'
# ds.get('ImagePositionPatient')[-1] = '1583.0'
# ds.get('ImagePositionPatient')[-1] = '1583.5'
# ds.get('ImagePositionPatient')[-1] = '1584.0'
# ds.get('ImagePositionPatient')[-1] = '1584.5'
# ds.get('ImagePositionPatient')[-1] = '1585.0'
# ds.get('ImagePositionPatient')[-1] = '1585.5'
# ds.get('ImagePositionPatient')[-1] = '1586.0'
# ds.get('ImagePositionPatient')[-1] = '1586.5'
# ds.get('ImagePositionPatient')[-1] = '1587.0'
# ds.get('ImagePositionPatient')[-1] = '1587.5'
# ds.get('ImagePositionPatient')[-1] = '1588.0'
# ds.get('ImagePositionPatient')[-1] = '1588.5'
# ds.get('ImagePositionPatient')[-1] = '1589.0'
# ds.get('ImagePositionPatient')[-1] = '1589.5'
# ds.get('ImagePositionPatient')[-1] = '1590.0'
# ds.get('ImagePositionPatient')[-1] = '1590.5'
# ds.get('ImagePositionPatient')[-1] = '1591.0'
# ds.get('ImagePositionPatient')[-1] = '1591.5'
# ds.get('ImagePositionPatient')[-1] = '1592.0'
# ds.get('ImagePositionPatient')[-1] = '1592.5'
# ds.get('ImagePositionPatient')[-1] = '1593.0'
# ds.get('ImagePositionPatient')[-1] = '1593.5'
# ds.get('ImagePositionPatient')[-1] = '1594.0'
# ds.get('ImagePositionPatient')[-1] = '1594.5'
# ds.get('ImagePositionPatient')[-1] = '1595.0'
# ds.get('ImagePositionPatient')[-1] = '1595.5'
# ds.get('ImagePositionPatient')[-1] = '1596.0'
# ds.get('ImagePositionPatient')[-1] = '1596.5'
# ds.get('ImagePositionPatient')[-1] = '1597.0'
# ds.get('ImagePositionPatient')[-1] = '1597.5'
# ds.get('ImagePositionPatient')[-1] = '1598.0'
# ds.get('ImagePositionPatient')[-1] = '1598.5'
# ds.get('ImagePositionPatient')[-1] = '1599.0'
# ds.get('ImagePositionPatient')[-1] = '1599.5'
# ds.get('ImagePositionPatient')[-1] = '1600.0'
# ds.get('ImagePositionPatient')[-1] = '1600.5'
# ds.get('ImagePositionPatient')[-1] = '1601.0'
# ds.get('ImagePositionPatient')[-1] = '1601.5'
# ds.get('ImagePositionPatient')[-1] = '1602.0'
# ds.get('ImagePositionPatient')[-1] = '1602.5'
# ds.get('ImagePositionPatient')[-1] = '1603.0'
# ds.get('ImagePositionPatient')[-1] = '1603.5'
# ds.get('ImagePositionPatient')[-1] = '1604.0'
# ds.get('ImagePositionPatient')[-1] = '1604.5'
# ds.get('ImagePositionPatient')[-1] = '1605.0'
# ds.get('ImagePositionPatient')[-1] = '1605.5'
# ds.get('ImagePositionPatient')[-1] = '1606.0'
# ds.get('ImagePositionPatient')[-1] = '1606.5'
# ds.get('ImagePositionPatient')[-1] = '1607.0'
# ds.get('ImagePositionPatient')[-1] = '1607.5'
# ds.get('ImagePositionPatient')[-1] = '1608.0'
# ds.get('ImagePositionPatient')[-1] = '1608.5'
# ds.get('ImagePositionPatient')[-1] = '1609.0'
# ds.get('ImagePositionPatient')[-1] = '1609.5'
# ds.get('ImagePositionPatient')[-1] = '1610.0'
# ds.get('ImagePositionPatient')[-1] = '1610.5'
# ds.get('ImagePositionPatient')[-1] = '1611.0'
# ds.get('ImagePositionPatient')[-1] = '1611.5'
# ds.get('ImagePositionPatient')[-1] = '1612.0'
# ds.get('ImagePositionPatient')[-1] = '1612.5'
# ds.get('ImagePositionPatient')[-1] = '1613.0'
# ds.get('ImagePositionPatient')[-1] = '1613.5'
# ds.get('ImagePositionPatient')[-1] = '1614.0'
# ds.get('ImagePositionPatient')[-1] = '1614.5'
# ds.get('ImagePositionPatient')[-1] = '1615.0'
# ds.get('ImagePositionPatient')[-1] = '1615.5'
# ds.get('ImagePositionPatient')[-1] = '1616.0'
# ds.get('ImagePositionPatient')[-1] = '1616.5'
# ds.get('ImagePositionPatient')[-1] = '1617.0'
# ds.get('ImagePositionPatient')[-1] = '1617.5'
# ds.get('ImagePositionPatient')[-1] = '1618.0'
# ds.get('ImagePositionPatient')[-1] = '1618.5'
# ds.get('ImagePositionPatient')[-1] = '1619.0'
# ds.get('ImagePositionPatient')[-1] = '1619.5'
# ds.get('ImagePositionPatient')[-1] = '1620.0'
# ds.get('ImagePositionPatient')[-1] = '1620.5'
# ds.get('ImagePositionPatient')[-1] = '1621.0'
# ds.get('ImagePositionPatient')[-1] = '1621.5'
# ds.get('ImagePositionPatient')[-1] = '1622.0'
# ds.get('ImagePositionPatient')[-1] = '1622.5'
# ds.get('ImagePositionPatient')[-1] = '1623.0'
# ds.get('ImagePositionPatient')[-1] = '1623.5'
# ds.get('ImagePositionPatient')[-1] = '1624.0'
# ds.get('ImagePositionPatient')[-1] = '1624.5'
# ds.get('ImagePositionPatient')[-1] = '1625.0'
# ds.get('ImagePositionPatient')[-1] = '1625.5'
# ds.get('ImagePositionPatient')[-1] = '1626.0'
# ds.get('ImagePositionPatient')[-1] = '1626.5'
# ds.get('ImagePositionPatient')[-1] = '1627.0'
# ds.get('ImagePositionPatient')[-1] = '1627.5'
# ds.get('ImagePositionPatient')[-1] = '1628.0'
# ds.get('ImagePositionPatient')[-1] = '1628.5'
# ds.get('ImagePositionPatient')[-1] = '1629.0'
# ds.get('ImagePositionPatient')[-1] = '1629.5'
# ds.get('ImagePositionPatient')[-1] = '1630.0'
# ds.get('ImagePositionPatient')[-1] = '1630.5'
# ds.get('ImagePositionPatient')[-1] = '1631.0'
# ds.get('ImagePositionPatient')[-1] = '1631.5'
# ds.get('ImagePositionPatient')[-1] = '1632.0'
# ds.get('ImagePositionPatient')[-1] = '1632.5'
# ds.get('ImagePositionPatient')[-1] = '1633.0'
# ds.get('ImagePositionPatient')[-1] = '1633.5'
# ds.get('ImagePositionPatient')[-1] = '1634.0'
# ds.get('ImagePositionPatient')[-1] = '1634.5'
# ds.get('ImagePositionPatient')[-1] = '1635.0'
# ds.get('ImagePositionPatient')[-1] = '1635.5'
# ds.get('ImagePositionPatient')[-1] = '1636.0'
# ds.get('ImagePositionPatient')[-1] = '1636.5'
# ds.get('ImagePositionPatient')[-1] = '1637.0'
# ds.get('ImagePositionPatient')[-1] = '1637.5'
# ds.get('ImagePositionPatient')[-1] = '1638.0'
# ds.get('ImagePositionPatient')[-1] = '1638.5'
# ds.get('ImagePositionPatient')[-1] = '1639.0'
# ds.get('ImagePositionPatient')[-1] = '1639.5'
# ds.get('ImagePositionPatient')[-1] = '1640.0'
# ds.get('ImagePositionPatient')[-1] = '1640.5'
# ds.get('ImagePositionPatient')[-1] = '1641.0'
# ds.get('ImagePositionPatient')[-1] = '1641.5'
# ds.get('ImagePositionPatient')[-1] = '1642.0'
# ds.get('ImagePositionPatient')[-1] = '1642.5'
# ds.get('ImagePositionPatient')[-1] = '1643.0'
# ds.get('ImagePositionPatient')[-1] = '1643.5'
# ds.get('ImagePositionPatient')[-1] = '1644.0'
# ds.get('ImagePositionPatient')[-1] = '1644.5'
# ds.get('ImagePositionPatient')[-1] = '1645.0'
# ds.get('ImagePositionPatient')[-1] = '1645.5'
# ds.get('ImagePositionPatient')[-1] = '1646.0'
# ds.get('ImagePositionPatient')[-1] = '1646.5'
# ds.get('ImagePositionPatient')[-1] = '1647.0'
# ds.get('ImagePositionPatient')[-1] = '1647.5'
# ds.get('ImagePositionPatient')[-1] = '1648.0'
# ds.get('ImagePositionPatient')[-1] = '1648.5'
# ds.get('ImagePositionPatient')[-1] = '1649.0'
# ds.get('ImagePositionPatient')[-1] = '1649.5'
# ds.get('ImagePositionPatient')[-1] = '1650.0'
# ds.get('ImagePositionPatient')[-1] = '1650.5'
# ds.get('ImagePositionPatient')[-1] = '1651.0'
# ds.get('ImagePositionPatient')[-1] = '1651.5'
# ds.get('ImagePositionPatient')[-1] = '1652.0'
# ds.get('ImagePositionPatient')[-1] = '1652.5'
# ds.get('ImagePositionPatient')[-1] = '1653.0'
# ds.get('ImagePositionPatient')[-1] = '1653.5'
# ds.get('ImagePositionPatient')[-1] = '1654.0'
# ds.get('ImagePositionPatient')[-1] = '1654.5'
# ds.get('ImagePositionPatient')[-1] = '1655.0'
# ds.get('ImagePositionPatient')[-1] = '1655.5'
# ds.get('ImagePositionPatient')[-1] = '1656.0'
# ds.get('ImagePositionPatient')[-1] = '1656.5'
# ds.get('ImagePositionPatient')[-1] = '1657.0'
# ds.get('ImagePositionPatient')[-1] = '1657.5'
# ds.get('ImagePositionPatient')[-1] = '1658.0'
# ds.get('ImagePositionPatient')[-1] = '1658.5'
# ds.get('ImagePositionPatient')[-1] = '1659.0'
# ds.get('ImagePositionPatient')[-1] = '1659.5'
# ds.get('ImagePositionPatient')[-1] = '1660.0'
# ds.get('ImagePositionPatient')[-1] = '1660.5'
# ds.get('ImagePositionPatient')[-1] = '1661.0'
# ds.get('ImagePositionPatient')[-1] = '1661.5'
# ds.get('ImagePositionPatient')[-1] = '1662.0'
# ds.get('ImagePositionPatient')[-1] = '1662.5'
# ds.get('ImagePositionPatient')[-1] = '1663.0'
# ds.get('ImagePositionPatient')[-1] = '1663.5'
# ds.get('ImagePositionPatient')[-1] = '1664.0'
# ds.get('ImagePositionPatient')[-1] = '1664.5'
# ds.get('ImagePositionPatient')[-1] = '1665.0'
# ds.get('ImagePositionPatient')[-1] = '1665.5'
# ds.get('ImagePositionPatient')[-1] = '1666.0'
# ds.get('ImagePositionPatient')[-1] = '1666.5'
# ds.get('ImagePositionPatient')[-1] = '1667.0'
# ds.get('ImagePositionPatient')[-1] = '1667.5'
# ds.get('ImagePositionPatient')[-1] = '1668.0'
# ds.get('ImagePositionPatient')[-1] = '1668.5'
# ds.get('ImagePositionPatient')[-1] = '1669.0'
# ds.get('ImagePositionPatient')[-1] = '1669.5'
# ds.get('ImagePositionPatient')[-1] = '1670.0'
# ds.get('ImagePositionPatient')[-1] = '1670.5'
# ds.get('ImagePositionPatient')[-1] = '1671.0'
# ds.get('ImagePositionPatient')[-1] = '1671.5'
# ds.get('ImagePositionPatient')[-1] = '1672.0'
# ds.get('ImagePositionPatient')[-1] = '1672.5'
# ds.get('ImagePositionPatient')[-1] = '1673.0'
# ds.get('ImagePositionPatient')[-1] = '1673.5'
# ds.get('ImagePositionPatient')[-1] = '1674.0'
# ds.get('ImagePositionPatient')[-1] = '1674.5'
# ds.get('ImagePositionPatient')[-1] = '1675.0'
# ds.get('ImagePositionPatient')[-1] = '1675.5'
# ds.get('ImagePositionPatient')[-1] = '1676.0'
# ds.get('ImagePositionPatient')[-1] = '1676.5'
# ds.get('ImagePositionPatient')[-1] = '1677.0'
# ds.get('ImagePositionPatient')[-1] = '1677.5'
# ds.get('ImagePositionPatient')[-1] = '1678.0'
# ds.get('ImagePositionPatient')[-1] = '1678.5'
# ds.get('ImagePositionPatient')[-1] = '1679.0'
# ds.get('ImagePositionPatient')[-1] = '1679.5'
# ds.get('ImagePositionPatient')[-1] = '1680.0'
# ds.get('ImagePositionPatient')[-1] = '1680.5'
# ds.get('ImagePositionPatient')[-1] = '1681.0'
# ds.get('ImagePositionPatient')[-1] = '1681.5'
# ds.get('ImagePositionPatient')[-1] = '1682.0'
# ds.get('ImagePositionPatient')[-1] = '1682.5'
# ds.get('ImagePositionPatient')[-1] = '1683.0'
# ds.get('ImagePositionPatient')[-1] = '1683.5'
# ds.get('ImagePositionPatient')[-1] = '1684.0'
# ds.get('ImagePositionPatient')[-1] = '1684.5'
# ds.get('ImagePositionPatient')[-1] = '1685.0'
# ds.get('ImagePositionPatient')[-1] = '1685.5'
# ds.get('ImagePositionPatient')[-1] = '1686.0'
# ds.get('ImagePositionPatient')[-1] = '1686.5'
# ds.get('ImagePositionPatient')[-1] = '1687.0'
# ds.get('ImagePositionPatient')[-1] = '1687.5'
# ds.get('ImagePositionPatient')[-1] = '1688.0'
# ds.get('ImagePositionPatient')[-1] = '1688.5'
# ds.get('ImagePositionPatient')[-1] = '1689.0'

# %%
import nibabel as nib
from pydicom import FileDataset, Dataset

@define
class NIfTIToDICOM:
    path_to_nifti_file: str | Path = field(converter=Path)
    meta_list: list[dict] = field(factory=list)
    save_dirpath: str | Path = field(default="mai_output", converter=Path)
    

    def convert(self):
        volm = nib.load(self.path_to_nifti_file).get_fdata()
        assert volm.shape[0] == self.meta_list[0]['rows']
        assert volm.shape[1] == self.meta_list[0]['cols']
        assert volm.shape[2] == len(self.meta_list)
        
        self.save_dirpath.mkdir(parents=True, exist_ok=True)
        
        # TODO: Convert NIfTI to DICOM
        for i in range(volm.shape[2]):

            ds = FileDataset(
                filename_or_obj=str(self.save_dirpath / f'slice_{i + 1:04d}.dcm'),
                dataset=Dataset(), 
                file_meta=Dataset(), 
                preamble=b"\0" * 128
            )

            # Add necessary metadata
            ds.PatientID = self.meta_list[i]['patient_id']
            ds.StudyInstanceUID = self.meta_list[i]['study_uid']
            ds.SeriesInstanceUID = self.meta_list[i]['series_uid']
            ds.Modality = "CT"
            ds.BodyPartExamined = "CHEST"
            ds.Rows = volm.shape[0]
            ds.Columns = volm.shape[1]
            ds.ImagePositionPatient = self.meta_list[i]['imagepositionpatient']
            ds.file_meta.TransferSyntaxUID = self.meta_list[i]['transfer_syntax_uid']
            ds.SamplesPerPixel = self.meta_list[i]['samples_per_pixel'] 
            ds.BitsAllocated = self.meta_list[i]['bits_allocated']
            ds.PixelRepresentation = self.meta_list[i]['pixel_representation'] 

            
            # TODO: Save the DICOMs in `self.save_dirpath`
            ds.save_as(str(self.save_dirpath / f'slice_{i + 1:04d}.dcm'))

        return self.save_dirpath
    
saved_dirpath = NIfTIToDICOM(path_to_nifti_file, meta_list).convert()
# Out:
# C:\Users\Lekhashree\anaconda3\lib\site-packages\pydicom\filewriter.py:1054: UserWarning: All encapsulated (compressed) transfer syntaxes must use explicit VR little endian encoding for the dataset. Set 'FileDataset.is_little_endian = True' and 'FileDataset.is_implicit_VR = False' before saving
#   warnings.warn(

# %% [markdown]
# # Verify new DICOMs

# %%
paths_list = list(saved_dirpath.glob("*.dcm"))
path_to_nifti_file, meta_list = DICOMToNIfTI(paths_list).convert()
# Out:
# C:\Users\Lekhashree\anaconda3\lib\site-packages\pydicom\filereader.py:353: UserWarning: Expected explicit VR, but found implicit VR - using implicit VR for reading
#   warnings.warn(msg + f" - using {found_vr} VR for reading", UserWarning)
# ds.get('ImagePositionPatient')[-1] = '1269.0'
# ds.get('ImagePositionPatient')[-1] = '1269.5'
# ds.get('ImagePositionPatient')[-1] = '1270.0'
# ds.get('ImagePositionPatient')[-1] = '1270.5'
# ds.get('ImagePositionPatient')[-1] = '1271.0'
# ds.get('ImagePositionPatient')[-1] = '1271.5'
# ds.get('ImagePositionPatient')[-1] = '1272.0'
# ds.get('ImagePositionPatient')[-1] = '1272.5'
# ds.get('ImagePositionPatient')[-1] = '1273.0'
# ds.get('ImagePositionPatient')[-1] = '1273.5'
# ds.get('ImagePositionPatient')[-1] = '1274.0'
# ds.get('ImagePositionPatient')[-1] = '1274.5'
# ds.get('ImagePositionPatient')[-1] = '1275.0'
# ds.get('ImagePositionPatient')[-1] = '1275.5'
# ds.get('ImagePositionPatient')[-1] = '1276.0'
# ds.get('ImagePositionPatient')[-1] = '1276.5'
# ds.get('ImagePositionPatient')[-1] = '1277.0'
# ds.get('ImagePositionPatient')[-1] = '1277.5'
# ds.get('ImagePositionPatient')[-1] = '1278.0'
# ds.get('ImagePositionPatient')[-1] = '1278.5'
# ds.get('ImagePositionPatient')[-1] = '1279.0'
# ds.get('ImagePositionPatient')[-1] = '1279.5'
# ds.get('ImagePositionPatient')[-1] = '1280.0'
# ds.get('ImagePositionPatient')[-1] = '1280.5'
# ds.get('ImagePositionPatient')[-1] = '1281.0'
# ds.get('ImagePositionPatient')[-1] = '1281.5'
# ds.get('ImagePositionPatient')[-1] = '1282.0'
# ds.get('ImagePositionPatient')[-1] = '1282.5'
# ds.get('ImagePositionPatient')[-1] = '1283.0'
# ds.get('ImagePositionPatient')[-1] = '1283.5'
# ds.get('ImagePositionPatient')[-1] = '1284.0'
# ds.get('ImagePositionPatient')[-1] = '1284.5'
# ds.get('ImagePositionPatient')[-1] = '1285.0'
# ds.get('ImagePositionPatient')[-1] = '1285.5'
# ds.get('ImagePositionPatient')[-1] = '1286.0'
# ds.get('ImagePositionPatient')[-1] = '1286.5'
# ds.get('ImagePositionPatient')[-1] = '1287.0'
# ds.get('ImagePositionPatient')[-1] = '1287.5'
# ds.get('ImagePositionPatient')[-1] = '1288.0'
# ds.get('ImagePositionPatient')[-1] = '1288.5'
# ds.get('ImagePositionPatient')[-1] = '1289.0'
# ds.get('ImagePositionPatient')[-1] = '1289.5'
# ds.get('ImagePositionPatient')[-1] = '1290.0'
# ds.get('ImagePositionPatient')[-1] = '1290.5'
# ds.get('ImagePositionPatient')[-1] = '1291.0'
# ds.get('ImagePositionPatient')[-1] = '1291.5'
# ds.get('ImagePositionPatient')[-1] = '1292.0'
# ds.get('ImagePositionPatient')[-1] = '1292.5'
# ds.get('ImagePositionPatient')[-1] = '1293.0'
# ds.get('ImagePositionPatient')[-1] = '1293.5'
# ds.get('ImagePositionPatient')[-1] = '1294.0'
# ds.get('ImagePositionPatient')[-1] = '1294.5'
# ds.get('ImagePositionPatient')[-1] = '1295.0'
# ds.get('ImagePositionPatient')[-1] = '1295.5'
# ds.get('ImagePositionPatient')[-1] = '1296.0'
# ds.get('ImagePositionPatient')[-1] = '1296.5'
# ds.get('ImagePositionPatient')[-1] = '1297.0'
# ds.get('ImagePositionPatient')[-1] = '1297.5'
# ds.get('ImagePositionPatient')[-1] = '1298.0'
# ds.get('ImagePositionPatient')[-1] = '1298.5'
# ds.get('ImagePositionPatient')[-1] = '1299.0'
# ds.get('ImagePositionPatient')[-1] = '1299.5'
# ds.get('ImagePositionPatient')[-1] = '1300.0'
# ds.get('ImagePositionPatient')[-1] = '1300.5'
# ds.get('ImagePositionPatient')[-1] = '1301.0'
# ds.get('ImagePositionPatient')[-1] = '1301.5'
# ds.get('ImagePositionPatient')[-1] = '1302.0'
# ds.get('ImagePositionPatient')[-1] = '1302.5'
# ds.get('ImagePositionPatient')[-1] = '1303.0'
# ds.get('ImagePositionPatient')[-1] = '1303.5'
# ds.get('ImagePositionPatient')[-1] = '1304.0'
# ds.get('ImagePositionPatient')[-1] = '1304.5'
# ds.get('ImagePositionPatient')[-1] = '1305.0'
# ds.get('ImagePositionPatient')[-1] = '1305.5'
# ds.get('ImagePositionPatient')[-1] = '1306.0'
# ds.get('ImagePositionPatient')[-1] = '1306.5'
# ds.get('ImagePositionPatient')[-1] = '1307.0'
# ds.get('ImagePositionPatient')[-1] = '1307.5'
# ds.get('ImagePositionPatient')[-1] = '1308.0'
# ds.get('ImagePositionPatient')[-1] = '1308.5'
# ds.get('ImagePositionPatient')[-1] = '1309.0'
# ds.get('ImagePositionPatient')[-1] = '1309.5'
# ds.get('ImagePositionPatient')[-1] = '1310.0'
# ds.get('ImagePositionPatient')[-1] = '1310.5'
# ds.get('ImagePositionPatient')[-1] = '1311.0'
# ds.get('ImagePositionPatient')[-1] = '1311.5'
# ds.get('ImagePositionPatient')[-1] = '1312.0'
# ds.get('ImagePositionPatient')[-1] = '1312.5'
# ds.get('ImagePositionPatient')[-1] = '1313.0'
# ds.get('ImagePositionPatient')[-1] = '1313.5'
# ds.get('ImagePositionPatient')[-1] = '1314.0'
# ds.get('ImagePositionPatient')[-1] = '1314.5'
# ds.get('ImagePositionPatient')[-1] = '1315.0'
# ds.get('ImagePositionPatient')[-1] = '1315.5'
# ds.get('ImagePositionPatient')[-1] = '1316.0'
# ds.get('ImagePositionPatient')[-1] = '1316.5'
# ds.get('ImagePositionPatient')[-1] = '1317.0'
# ds.get('ImagePositionPatient')[-1] = '1317.5'
# ds.get('ImagePositionPatient')[-1] = '1318.0'
# ds.get('ImagePositionPatient')[-1] = '1318.5'
# ds.get('ImagePositionPatient')[-1] = '1319.0'
# ds.get('ImagePositionPatient')[-1] = '1319.5'
# ds.get('ImagePositionPatient')[-1] = '1320.0'
# ds.get('ImagePositionPatient')[-1] = '1320.5'
# ds.get('ImagePositionPatient')[-1] = '1321.0'
# ds.get('ImagePositionPatient')[-1] = '1321.5'
# ds.get('ImagePositionPatient')[-1] = '1322.0'
# ds.get('ImagePositionPatient')[-1] = '1322.5'
# ds.get('ImagePositionPatient')[-1] = '1323.0'
# ds.get('ImagePositionPatient')[-1] = '1323.5'
# ds.get('ImagePositionPatient')[-1] = '1324.0'
# ds.get('ImagePositionPatient')[-1] = '1324.5'
# ds.get('ImagePositionPatient')[-1] = '1325.0'
# ds.get('ImagePositionPatient')[-1] = '1325.5'
# ds.get('ImagePositionPatient')[-1] = '1326.0'
# ds.get('ImagePositionPatient')[-1] = '1326.5'
# ds.get('ImagePositionPatient')[-1] = '1327.0'
# ds.get('ImagePositionPatient')[-1] = '1327.5'
# ds.get('ImagePositionPatient')[-1] = '1328.0'
# ds.get('ImagePositionPatient')[-1] = '1328.5'
# ds.get('ImagePositionPatient')[-1] = '1329.0'
# ds.get('ImagePositionPatient')[-1] = '1329.5'
# ds.get('ImagePositionPatient')[-1] = '1330.0'
# ds.get('ImagePositionPatient')[-1] = '1330.5'
# ds.get('ImagePositionPatient')[-1] = '1331.0'
# ds.get('ImagePositionPatient')[-1] = '1331.5'
# ds.get('ImagePositionPatient')[-1] = '1332.0'
# ds.get('ImagePositionPatient')[-1] = '1332.5'
# ds.get('ImagePositionPatient')[-1] = '1333.0'
# ds.get('ImagePositionPatient')[-1] = '1333.5'
# ds.get('ImagePositionPatient')[-1] = '1334.0'
# ds.get('ImagePositionPatient')[-1] = '1334.5'
# ds.get('ImagePositionPatient')[-1] = '1335.0'
# ds.get('ImagePositionPatient')[-1] = '1335.5'
# ds.get('ImagePositionPatient')[-1] = '1336.0'
# ds.get('ImagePositionPatient')[-1] = '1336.5'
# ds.get('ImagePositionPatient')[-1] = '1337.0'
# ds.get('ImagePositionPatient')[-1] = '1337.5'
# ds.get('ImagePositionPatient')[-1] = '1338.0'
# ds.get('ImagePositionPatient')[-1] = '1338.5'
# ds.get('ImagePositionPatient')[-1] = '1339.0'
# ds.get('ImagePositionPatient')[-1] = '1339.5'
# ds.get('ImagePositionPatient')[-1] = '1340.0'
# ds.get('ImagePositionPatient')[-1] = '1340.5'
# ds.get('ImagePositionPatient')[-1] = '1341.0'
# ds.get('ImagePositionPatient')[-1] = '1341.5'
# ds.get('ImagePositionPatient')[-1] = '1342.0'
# ds.get('ImagePositionPatient')[-1] = '1342.5'
# ds.get('ImagePositionPatient')[-1] = '1343.0'
# ds.get('ImagePositionPatient')[-1] = '1343.5'
# ds.get('ImagePositionPatient')[-1] = '1344.0'
# ds.get('ImagePositionPatient')[-1] = '1344.5'
# ds.get('ImagePositionPatient')[-1] = '1345.0'
# ds.get('ImagePositionPatient')[-1] = '1345.5'
# ds.get('ImagePositionPatient')[-1] = '1346.0'
# ds.get('ImagePositionPatient')[-1] = '1346.5'
# ds.get('ImagePositionPatient')[-1] = '1347.0'
# ds.get('ImagePositionPatient')[-1] = '1347.5'
# ds.get('ImagePositionPatient')[-1] = '1348.0'
# ds.get('ImagePositionPatient')[-1] = '1348.5'
# ds.get('ImagePositionPatient')[-1] = '1349.0'
# ds.get('ImagePositionPatient')[-1] = '1349.5'
# ds.get('ImagePositionPatient')[-1] = '1350.0'
# ds.get('ImagePositionPatient')[-1] = '1350.5'
# ds.get('ImagePositionPatient')[-1] = '1351.0'
# ds.get('ImagePositionPatient')[-1] = '1351.5'
# ds.get('ImagePositionPatient')[-1] = '1352.0'
# ds.get('ImagePositionPatient')[-1] = '1352.5'
# ds.get('ImagePositionPatient')[-1] = '1353.0'
# ds.get('ImagePositionPatient')[-1] = '1353.5'
# ds.get('ImagePositionPatient')[-1] = '1354.0'
# ds.get('ImagePositionPatient')[-1] = '1354.5'
# ds.get('ImagePositionPatient')[-1] = '1355.0'
# ds.get('ImagePositionPatient')[-1] = '1355.5'
# ds.get('ImagePositionPatient')[-1] = '1356.0'
# ds.get('ImagePositionPatient')[-1] = '1356.5'
# ds.get('ImagePositionPatient')[-1] = '1357.0'
# ds.get('ImagePositionPatient')[-1] = '1357.5'
# ds.get('ImagePositionPatient')[-1] = '1358.0'
# ds.get('ImagePositionPatient')[-1] = '1358.5'
# ds.get('ImagePositionPatient')[-1] = '1359.0'
# ds.get('ImagePositionPatient')[-1] = '1359.5'
# ds.get('ImagePositionPatient')[-1] = '1360.0'
# ds.get('ImagePositionPatient')[-1] = '1360.5'
# ds.get('ImagePositionPatient')[-1] = '1361.0'
# ds.get('ImagePositionPatient')[-1] = '1361.5'
# ds.get('ImagePositionPatient')[-1] = '1362.0'
# ds.get('ImagePositionPatient')[-1] = '1362.5'
# ds.get('ImagePositionPatient')[-1] = '1363.0'
# ds.get('ImagePositionPatient')[-1] = '1363.5'
# ds.get('ImagePositionPatient')[-1] = '1364.0'
# ds.get('ImagePositionPatient')[-1] = '1364.5'
# ds.get('ImagePositionPatient')[-1] = '1365.0'
# ds.get('ImagePositionPatient')[-1] = '1365.5'
# ds.get('ImagePositionPatient')[-1] = '1366.0'
# ds.get('ImagePositionPatient')[-1] = '1366.5'
# ds.get('ImagePositionPatient')[-1] = '1367.0'
# ds.get('ImagePositionPatient')[-1] = '1367.5'
# ds.get('ImagePositionPatient')[-1] = '1368.0'
# ds.get('ImagePositionPatient')[-1] = '1368.5'
# ds.get('ImagePositionPatient')[-1] = '1369.0'
# ds.get('ImagePositionPatient')[-1] = '1369.5'
# ds.get('ImagePositionPatient')[-1] = '1370.0'
# ds.get('ImagePositionPatient')[-1] = '1370.5'
# ds.get('ImagePositionPatient')[-1] = '1371.0'
# ds.get('ImagePositionPatient')[-1] = '1371.5'
# ds.get('ImagePositionPatient')[-1] = '1372.0'
# ds.get('ImagePositionPatient')[-1] = '1372.5'
# ds.get('ImagePositionPatient')[-1] = '1373.0'
# ds.get('ImagePositionPatient')[-1] = '1373.5'
# ds.get('ImagePositionPatient')[-1] = '1374.0'
# ds.get('ImagePositionPatient')[-1] = '1374.5'
# ds.get('ImagePositionPatient')[-1] = '1375.0'
# ds.get('ImagePositionPatient')[-1] = '1375.5'
# ds.get('ImagePositionPatient')[-1] = '1376.0'
# ds.get('ImagePositionPatient')[-1] = '1376.5'
# ds.get('ImagePositionPatient')[-1] = '1377.0'
# ds.get('ImagePositionPatient')[-1] = '1377.5'
# ds.get('ImagePositionPatient')[-1] = '1378.0'
# ds.get('ImagePositionPatient')[-1] = '1378.5'
# ds.get('ImagePositionPatient')[-1] = '1379.0'
# ds.get('ImagePositionPatient')[-1] = '1379.5'
# ds.get('ImagePositionPatient')[-1] = '1380.0'
# ds.get('ImagePositionPatient')[-1] = '1380.5'
# ds.get('ImagePositionPatient')[-1] = '1381.0'
# ds.get('ImagePositionPatient')[-1] = '1381.5'
# ds.get('ImagePositionPatient')[-1] = '1382.0'
# ds.get('ImagePositionPatient')[-1] = '1382.5'
# ds.get('ImagePositionPatient')[-1] = '1383.0'
# ds.get('ImagePositionPatient')[-1] = '1383.5'
# ds.get('ImagePositionPatient')[-1] = '1384.0'
# ds.get('ImagePositionPatient')[-1] = '1384.5'
# ds.get('ImagePositionPatient')[-1] = '1385.0'
# ds.get('ImagePositionPatient')[-1] = '1385.5'
# ds.get('ImagePositionPatient')[-1] = '1386.0'
# ds.get('ImagePositionPatient')[-1] = '1386.5'
# ds.get('ImagePositionPatient')[-1] = '1387.0'
# ds.get('ImagePositionPatient')[-1] = '1387.5'
# ds.get('ImagePositionPatient')[-1] = '1388.0'
# ds.get('ImagePositionPatient')[-1] = '1388.5'
# ds.get('ImagePositionPatient')[-1] = '1389.0'
# ds.get('ImagePositionPatient')[-1] = '1389.5'
# ds.get('ImagePositionPatient')[-1] = '1390.0'
# ds.get('ImagePositionPatient')[-1] = '1390.5'
# ds.get('ImagePositionPatient')[-1] = '1391.0'
# ds.get('ImagePositionPatient')[-1] = '1391.5'
# ds.get('ImagePositionPatient')[-1] = '1392.0'
# ds.get('ImagePositionPatient')[-1] = '1392.5'
# ds.get('ImagePositionPatient')[-1] = '1393.0'
# ds.get('ImagePositionPatient')[-1] = '1393.5'
# ds.get('ImagePositionPatient')[-1] = '1394.0'
# ds.get('ImagePositionPatient')[-1] = '1394.5'
# ds.get('ImagePositionPatient')[-1] = '1395.0'
# ds.get('ImagePositionPatient')[-1] = '1395.5'
# ds.get('ImagePositionPatient')[-1] = '1396.0'
# ds.get('ImagePositionPatient')[-1] = '1396.5'
# ds.get('ImagePositionPatient')[-1] = '1397.0'
# ds.get('ImagePositionPatient')[-1] = '1397.5'
# ds.get('ImagePositionPatient')[-1] = '1398.0'
# ds.get('ImagePositionPatient')[-1] = '1398.5'
# ds.get('ImagePositionPatient')[-1] = '1399.0'
# ds.get('ImagePositionPatient')[-1] = '1399.5'
# ds.get('ImagePositionPatient')[-1] = '1400.0'
# ds.get('ImagePositionPatient')[-1] = '1400.5'
# ds.get('ImagePositionPatient')[-1] = '1401.0'
# ds.get('ImagePositionPatient')[-1] = '1401.5'
# ds.get('ImagePositionPatient')[-1] = '1402.0'
# ds.get('ImagePositionPatient')[-1] = '1402.5'
# ds.get('ImagePositionPatient')[-1] = '1403.0'
# ds.get('ImagePositionPatient')[-1] = '1403.5'
# ds.get('ImagePositionPatient')[-1] = '1404.0'
# ds.get('ImagePositionPatient')[-1] = '1404.5'
# ds.get('ImagePositionPatient')[-1] = '1405.0'
# ds.get('ImagePositionPatient')[-1] = '1405.5'
# ds.get('ImagePositionPatient')[-1] = '1406.0'
# ds.get('ImagePositionPatient')[-1] = '1406.5'
# ds.get('ImagePositionPatient')[-1] = '1407.0'
# ds.get('ImagePositionPatient')[-1] = '1407.5'
# ds.get('ImagePositionPatient')[-1] = '1408.0'
# ds.get('ImagePositionPatient')[-1] = '1408.5'
# ds.get('ImagePositionPatient')[-1] = '1409.0'
# ds.get('ImagePositionPatient')[-1] = '1409.5'
# ds.get('ImagePositionPatient')[-1] = '1410.0'
# ds.get('ImagePositionPatient')[-1] = '1410.5'
# ds.get('ImagePositionPatient')[-1] = '1411.0'
# ds.get('ImagePositionPatient')[-1] = '1411.5'
# ds.get('ImagePositionPatient')[-1] = '1412.0'
# ds.get('ImagePositionPatient')[-1] = '1412.5'
# ds.get('ImagePositionPatient')[-1] = '1413.0'
# ds.get('ImagePositionPatient')[-1] = '1413.5'
# ds.get('ImagePositionPatient')[-1] = '1414.0'
# ds.get('ImagePositionPatient')[-1] = '1414.5'
# ds.get('ImagePositionPatient')[-1] = '1415.0'
# ds.get('ImagePositionPatient')[-1] = '1415.5'
# ds.get('ImagePositionPatient')[-1] = '1416.0'
# ds.get('ImagePositionPatient')[-1] = '1416.5'
# ds.get('ImagePositionPatient')[-1] = '1417.0'
# ds.get('ImagePositionPatient')[-1] = '1417.5'
# ds.get('ImagePositionPatient')[-1] = '1418.0'
# ds.get('ImagePositionPatient')[-1] = '1418.5'
# ds.get('ImagePositionPatient')[-1] = '1419.0'
# ds.get('ImagePositionPatient')[-1] = '1419.5'
# ds.get('ImagePositionPatient')[-1] = '1420.0'
# ds.get('ImagePositionPatient')[-1] = '1420.5'
# ds.get('ImagePositionPatient')[-1] = '1421.0'
# ds.get('ImagePositionPatient')[-1] = '1421.5'
# ds.get('ImagePositionPatient')[-1] = '1422.0'
# ds.get('ImagePositionPatient')[-1] = '1422.5'
# ds.get('ImagePositionPatient')[-1] = '1423.0'
# ds.get('ImagePositionPatient')[-1] = '1423.5'
# ds.get('ImagePositionPatient')[-1] = '1424.0'
# ds.get('ImagePositionPatient')[-1] = '1424.5'
# ds.get('ImagePositionPatient')[-1] = '1425.0'
# ds.get('ImagePositionPatient')[-1] = '1425.5'
# ds.get('ImagePositionPatient')[-1] = '1426.0'
# ds.get('ImagePositionPatient')[-1] = '1426.5'
# ds.get('ImagePositionPatient')[-1] = '1427.0'
# ds.get('ImagePositionPatient')[-1] = '1427.5'
# ds.get('ImagePositionPatient')[-1] = '1428.0'
# ds.get('ImagePositionPatient')[-1] = '1428.5'
# ds.get('ImagePositionPatient')[-1] = '1429.0'
# ds.get('ImagePositionPatient')[-1] = '1429.5'
# ds.get('ImagePositionPatient')[-1] = '1430.0'
# ds.get('ImagePositionPatient')[-1] = '1430.5'
# ds.get('ImagePositionPatient')[-1] = '1431.0'
# ds.get('ImagePositionPatient')[-1] = '1431.5'
# ds.get('ImagePositionPatient')[-1] = '1432.0'
# ds.get('ImagePositionPatient')[-1] = '1432.5'
# ds.get('ImagePositionPatient')[-1] = '1433.0'
# ds.get('ImagePositionPatient')[-1] = '1433.5'
# ds.get('ImagePositionPatient')[-1] = '1434.0'
# ds.get('ImagePositionPatient')[-1] = '1434.5'
# ds.get('ImagePositionPatient')[-1] = '1435.0'
# ds.get('ImagePositionPatient')[-1] = '1435.5'
# ds.get('ImagePositionPatient')[-1] = '1436.0'
# ds.get('ImagePositionPatient')[-1] = '1436.5'
# ds.get('ImagePositionPatient')[-1] = '1437.0'
# ds.get('ImagePositionPatient')[-1] = '1437.5'
# ds.get('ImagePositionPatient')[-1] = '1438.0'
# ds.get('ImagePositionPatient')[-1] = '1438.5'
# ds.get('ImagePositionPatient')[-1] = '1439.0'
# ds.get('ImagePositionPatient')[-1] = '1439.5'
# ds.get('ImagePositionPatient')[-1] = '1440.0'
# ds.get('ImagePositionPatient')[-1] = '1440.5'
# ds.get('ImagePositionPatient')[-1] = '1441.0'
# ds.get('ImagePositionPatient')[-1] = '1441.5'
# ds.get('ImagePositionPatient')[-1] = '1442.0'
# ds.get('ImagePositionPatient')[-1] = '1442.5'
# ds.get('ImagePositionPatient')[-1] = '1443.0'
# ds.get('ImagePositionPatient')[-1] = '1443.5'
# ds.get('ImagePositionPatient')[-1] = '1444.0'
# ds.get('ImagePositionPatient')[-1] = '1444.5'
# ds.get('ImagePositionPatient')[-1] = '1445.0'
# ds.get('ImagePositionPatient')[-1] = '1445.5'
# ds.get('ImagePositionPatient')[-1] = '1446.0'
# ds.get('ImagePositionPatient')[-1] = '1446.5'
# ds.get('ImagePositionPatient')[-1] = '1447.0'
# ds.get('ImagePositionPatient')[-1] = '1447.5'
# ds.get('ImagePositionPatient')[-1] = '1448.0'
# ds.get('ImagePositionPatient')[-1] = '1448.5'
# ds.get('ImagePositionPatient')[-1] = '1449.0'
# ds.get('ImagePositionPatient')[-1] = '1449.5'
# ds.get('ImagePositionPatient')[-1] = '1450.0'
# ds.get('ImagePositionPatient')[-1] = '1450.5'
# ds.get('ImagePositionPatient')[-1] = '1451.0'
# ds.get('ImagePositionPatient')[-1] = '1451.5'
# ds.get('ImagePositionPatient')[-1] = '1452.0'
# ds.get('ImagePositionPatient')[-1] = '1452.5'
# ds.get('ImagePositionPatient')[-1] = '1453.0'
# ds.get('ImagePositionPatient')[-1] = '1453.5'
# ds.get('ImagePositionPatient')[-1] = '1454.0'
# ds.get('ImagePositionPatient')[-1] = '1454.5'
# ds.get('ImagePositionPatient')[-1] = '1455.0'
# ds.get('ImagePositionPatient')[-1] = '1455.5'
# ds.get('ImagePositionPatient')[-1] = '1456.0'
# ds.get('ImagePositionPatient')[-1] = '1456.5'
# ds.get('ImagePositionPatient')[-1] = '1457.0'
# ds.get('ImagePositionPatient')[-1] = '1457.5'
# ds.get('ImagePositionPatient')[-1] = '1458.0'
# ds.get('ImagePositionPatient')[-1] = '1458.5'
# ds.get('ImagePositionPatient')[-1] = '1459.0'
# ds.get('ImagePositionPatient')[-1] = '1459.5'
# ds.get('ImagePositionPatient')[-1] = '1460.0'
# ds.get('ImagePositionPatient')[-1] = '1460.5'
# ds.get('ImagePositionPatient')[-1] = '1461.0'
# ds.get('ImagePositionPatient')[-1] = '1461.5'
# ds.get('ImagePositionPatient')[-1] = '1462.0'
# ds.get('ImagePositionPatient')[-1] = '1462.5'
# ds.get('ImagePositionPatient')[-1] = '1463.0'
# ds.get('ImagePositionPatient')[-1] = '1463.5'
# ds.get('ImagePositionPatient')[-1] = '1464.0'
# ds.get('ImagePositionPatient')[-1] = '1464.5'
# ds.get('ImagePositionPatient')[-1] = '1465.0'
# ds.get('ImagePositionPatient')[-1] = '1465.5'
# ds.get('ImagePositionPatient')[-1] = '1466.0'
# ds.get('ImagePositionPatient')[-1] = '1466.5'
# ds.get('ImagePositionPatient')[-1] = '1467.0'
# ds.get('ImagePositionPatient')[-1] = '1467.5'
# ds.get('ImagePositionPatient')[-1] = '1468.0'
# ds.get('ImagePositionPatient')[-1] = '1468.5'
# ds.get('ImagePositionPatient')[-1] = '1469.0'
# ds.get('ImagePositionPatient')[-1] = '1469.5'
# ds.get('ImagePositionPatient')[-1] = '1470.0'
# ds.get('ImagePositionPatient')[-1] = '1470.5'
# ds.get('ImagePositionPatient')[-1] = '1471.0'
# ds.get('ImagePositionPatient')[-1] = '1471.5'
# ds.get('ImagePositionPatient')[-1] = '1472.0'
# ds.get('ImagePositionPatient')[-1] = '1472.5'
# ds.get('ImagePositionPatient')[-1] = '1473.0'
# ds.get('ImagePositionPatient')[-1] = '1473.5'
# ds.get('ImagePositionPatient')[-1] = '1474.0'
# ds.get('ImagePositionPatient')[-1] = '1474.5'
# ds.get('ImagePositionPatient')[-1] = '1475.0'
# ds.get('ImagePositionPatient')[-1] = '1475.5'
# ds.get('ImagePositionPatient')[-1] = '1476.0'
# ds.get('ImagePositionPatient')[-1] = '1476.5'
# ds.get('ImagePositionPatient')[-1] = '1477.0'
# ds.get('ImagePositionPatient')[-1] = '1477.5'
# ds.get('ImagePositionPatient')[-1] = '1478.0'
# ds.get('ImagePositionPatient')[-1] = '1478.5'
# ds.get('ImagePositionPatient')[-1] = '1479.0'
# ds.get('ImagePositionPatient')[-1] = '1479.5'
# ds.get('ImagePositionPatient')[-1] = '1480.0'
# ds.get('ImagePositionPatient')[-1] = '1480.5'
# ds.get('ImagePositionPatient')[-1] = '1481.0'
# ds.get('ImagePositionPatient')[-1] = '1481.5'
# ds.get('ImagePositionPatient')[-1] = '1482.0'
# ds.get('ImagePositionPatient')[-1] = '1482.5'
# ds.get('ImagePositionPatient')[-1] = '1483.0'
# ds.get('ImagePositionPatient')[-1] = '1483.5'
# ds.get('ImagePositionPatient')[-1] = '1484.0'
# ds.get('ImagePositionPatient')[-1] = '1484.5'
# ds.get('ImagePositionPatient')[-1] = '1485.0'
# ds.get('ImagePositionPatient')[-1] = '1485.5'
# ds.get('ImagePositionPatient')[-1] = '1486.0'
# ds.get('ImagePositionPatient')[-1] = '1486.5'
# ds.get('ImagePositionPatient')[-1] = '1487.0'
# ds.get('ImagePositionPatient')[-1] = '1487.5'
# ds.get('ImagePositionPatient')[-1] = '1488.0'
# ds.get('ImagePositionPatient')[-1] = '1488.5'
# ds.get('ImagePositionPatient')[-1] = '1489.0'
# ds.get('ImagePositionPatient')[-1] = '1489.5'
# ds.get('ImagePositionPatient')[-1] = '1490.0'
# ds.get('ImagePositionPatient')[-1] = '1490.5'
# ds.get('ImagePositionPatient')[-1] = '1491.0'
# ds.get('ImagePositionPatient')[-1] = '1491.5'
# ds.get('ImagePositionPatient')[-1] = '1492.0'
# ds.get('ImagePositionPatient')[-1] = '1492.5'
# ds.get('ImagePositionPatient')[-1] = '1493.0'
# ds.get('ImagePositionPatient')[-1] = '1493.5'
# ds.get('ImagePositionPatient')[-1] = '1494.0'
# ds.get('ImagePositionPatient')[-1] = '1494.5'
# ds.get('ImagePositionPatient')[-1] = '1495.0'
# ds.get('ImagePositionPatient')[-1] = '1495.5'
# ds.get('ImagePositionPatient')[-1] = '1496.0'
# ds.get('ImagePositionPatient')[-1] = '1496.5'
# ds.get('ImagePositionPatient')[-1] = '1497.0'
# ds.get('ImagePositionPatient')[-1] = '1497.5'
# ds.get('ImagePositionPatient')[-1] = '1498.0'
# ds.get('ImagePositionPatient')[-1] = '1498.5'
# ds.get('ImagePositionPatient')[-1] = '1499.0'
# ds.get('ImagePositionPatient')[-1] = '1499.5'
# ds.get('ImagePositionPatient')[-1] = '1500.0'
# ds.get('ImagePositionPatient')[-1] = '1500.5'
# ds.get('ImagePositionPatient')[-1] = '1501.0'
# ds.get('ImagePositionPatient')[-1] = '1501.5'
# ds.get('ImagePositionPatient')[-1] = '1502.0'
# ds.get('ImagePositionPatient')[-1] = '1502.5'
# ds.get('ImagePositionPatient')[-1] = '1503.0'
# ds.get('ImagePositionPatient')[-1] = '1503.5'
# ds.get('ImagePositionPatient')[-1] = '1504.0'
# ds.get('ImagePositionPatient')[-1] = '1504.5'
# ds.get('ImagePositionPatient')[-1] = '1505.0'
# ds.get('ImagePositionPatient')[-1] = '1505.5'
# ds.get('ImagePositionPatient')[-1] = '1506.0'
# ds.get('ImagePositionPatient')[-1] = '1506.5'
# ds.get('ImagePositionPatient')[-1] = '1507.0'
# ds.get('ImagePositionPatient')[-1] = '1507.5'
# ds.get('ImagePositionPatient')[-1] = '1508.0'
# ds.get('ImagePositionPatient')[-1] = '1508.5'
# ds.get('ImagePositionPatient')[-1] = '1509.0'
# ds.get('ImagePositionPatient')[-1] = '1509.5'
# ds.get('ImagePositionPatient')[-1] = '1510.0'
# ds.get('ImagePositionPatient')[-1] = '1510.5'
# ds.get('ImagePositionPatient')[-1] = '1511.0'
# ds.get('ImagePositionPatient')[-1] = '1511.5'
# ds.get('ImagePositionPatient')[-1] = '1512.0'
# ds.get('ImagePositionPatient')[-1] = '1512.5'
# ds.get('ImagePositionPatient')[-1] = '1513.0'
# ds.get('ImagePositionPatient')[-1] = '1513.5'
# ds.get('ImagePositionPatient')[-1] = '1514.0'
# ds.get('ImagePositionPatient')[-1] = '1514.5'
# ds.get('ImagePositionPatient')[-1] = '1515.0'
# ds.get('ImagePositionPatient')[-1] = '1515.5'
# ds.get('ImagePositionPatient')[-1] = '1516.0'
# ds.get('ImagePositionPatient')[-1] = '1516.5'
# ds.get('ImagePositionPatient')[-1] = '1517.0'
# ds.get('ImagePositionPatient')[-1] = '1517.5'
# ds.get('ImagePositionPatient')[-1] = '1518.0'
# ds.get('ImagePositionPatient')[-1] = '1518.5'
# ds.get('ImagePositionPatient')[-1] = '1519.0'
# ds.get('ImagePositionPatient')[-1] = '1519.5'
# ds.get('ImagePositionPatient')[-1] = '1520.0'
# ds.get('ImagePositionPatient')[-1] = '1520.5'
# ds.get('ImagePositionPatient')[-1] = '1521.0'
# ds.get('ImagePositionPatient')[-1] = '1521.5'
# ds.get('ImagePositionPatient')[-1] = '1522.0'
# ds.get('ImagePositionPatient')[-1] = '1522.5'
# ds.get('ImagePositionPatient')[-1] = '1523.0'
# ds.get('ImagePositionPatient')[-1] = '1523.5'
# ds.get('ImagePositionPatient')[-1] = '1524.0'
# ds.get('ImagePositionPatient')[-1] = '1524.5'
# ds.get('ImagePositionPatient')[-1] = '1525.0'
# ds.get('ImagePositionPatient')[-1] = '1525.5'
# ds.get('ImagePositionPatient')[-1] = '1526.0'
# ds.get('ImagePositionPatient')[-1] = '1526.5'
# ds.get('ImagePositionPatient')[-1] = '1527.0'
# ds.get('ImagePositionPatient')[-1] = '1527.5'
# ds.get('ImagePositionPatient')[-1] = '1528.0'
# ds.get('ImagePositionPatient')[-1] = '1528.5'
# ds.get('ImagePositionPatient')[-1] = '1529.0'
# ds.get('ImagePositionPatient')[-1] = '1529.5'
# ds.get('ImagePositionPatient')[-1] = '1530.0'
# ds.get('ImagePositionPatient')[-1] = '1530.5'
# ds.get('ImagePositionPatient')[-1] = '1531.0'
# ds.get('ImagePositionPatient')[-1] = '1531.5'
# ds.get('ImagePositionPatient')[-1] = '1532.0'
# ds.get('ImagePositionPatient')[-1] = '1532.5'
# ds.get('ImagePositionPatient')[-1] = '1533.0'
# ds.get('ImagePositionPatient')[-1] = '1533.5'
# ds.get('ImagePositionPatient')[-1] = '1534.0'
# ds.get('ImagePositionPatient')[-1] = '1534.5'
# ds.get('ImagePositionPatient')[-1] = '1535.0'
# ds.get('ImagePositionPatient')[-1] = '1535.5'
# ds.get('ImagePositionPatient')[-1] = '1536.0'
# ds.get('ImagePositionPatient')[-1] = '1536.5'
# ds.get('ImagePositionPatient')[-1] = '1537.0'
# ds.get('ImagePositionPatient')[-1] = '1537.5'
# ds.get('ImagePositionPatient')[-1] = '1538.0'
# ds.get('ImagePositionPatient')[-1] = '1538.5'
# ds.get('ImagePositionPatient')[-1] = '1539.0'
# ds.get('ImagePositionPatient')[-1] = '1539.5'
# ds.get('ImagePositionPatient')[-1] = '1540.0'
# ds.get('ImagePositionPatient')[-1] = '1540.5'
# ds.get('ImagePositionPatient')[-1] = '1541.0'
# ds.get('ImagePositionPatient')[-1] = '1541.5'
# ds.get('ImagePositionPatient')[-1] = '1542.0'
# ds.get('ImagePositionPatient')[-1] = '1542.5'
# ds.get('ImagePositionPatient')[-1] = '1543.0'
# ds.get('ImagePositionPatient')[-1] = '1543.5'
# ds.get('ImagePositionPatient')[-1] = '1544.0'
# ds.get('ImagePositionPatient')[-1] = '1544.5'
# ds.get('ImagePositionPatient')[-1] = '1545.0'
# ds.get('ImagePositionPatient')[-1] = '1545.5'
# ds.get('ImagePositionPatient')[-1] = '1546.0'
# ds.get('ImagePositionPatient')[-1] = '1546.5'
# ds.get('ImagePositionPatient')[-1] = '1547.0'
# ds.get('ImagePositionPatient')[-1] = '1547.5'
# ds.get('ImagePositionPatient')[-1] = '1548.0'
# ds.get('ImagePositionPatient')[-1] = '1548.5'
# ds.get('ImagePositionPatient')[-1] = '1549.0'
# ds.get('ImagePositionPatient')[-1] = '1549.5'
# ds.get('ImagePositionPatient')[-1] = '1550.0'
# ds.get('ImagePositionPatient')[-1] = '1550.5'
# ds.get('ImagePositionPatient')[-1] = '1551.0'
# ds.get('ImagePositionPatient')[-1] = '1551.5'
# ds.get('ImagePositionPatient')[-1] = '1552.0'
# ds.get('ImagePositionPatient')[-1] = '1552.5'
# ds.get('ImagePositionPatient')[-1] = '1553.0'
# ds.get('ImagePositionPatient')[-1] = '1553.5'
# ds.get('ImagePositionPatient')[-1] = '1554.0'
# ds.get('ImagePositionPatient')[-1] = '1554.5'
# ds.get('ImagePositionPatient')[-1] = '1555.0'
# ds.get('ImagePositionPatient')[-1] = '1555.5'
# ds.get('ImagePositionPatient')[-1] = '1556.0'
# ds.get('ImagePositionPatient')[-1] = '1556.5'
# ds.get('ImagePositionPatient')[-1] = '1557.0'
# ds.get('ImagePositionPatient')[-1] = '1557.5'
# ds.get('ImagePositionPatient')[-1] = '1558.0'
# ds.get('ImagePositionPatient')[-1] = '1558.5'
# ds.get('ImagePositionPatient')[-1] = '1559.0'
# ds.get('ImagePositionPatient')[-1] = '1559.5'
# ds.get('ImagePositionPatient')[-1] = '1560.0'
# ds.get('ImagePositionPatient')[-1] = '1560.5'
# ds.get('ImagePositionPatient')[-1] = '1561.0'
# ds.get('ImagePositionPatient')[-1] = '1561.5'
# ds.get('ImagePositionPatient')[-1] = '1562.0'
# ds.get('ImagePositionPatient')[-1] = '1562.5'
# ds.get('ImagePositionPatient')[-1] = '1563.0'
# ds.get('ImagePositionPatient')[-1] = '1563.5'
# ds.get('ImagePositionPatient')[-1] = '1564.0'
# ds.get('ImagePositionPatient')[-1] = '1564.5'
# ds.get('ImagePositionPatient')[-1] = '1565.0'
# ds.get('ImagePositionPatient')[-1] = '1565.5'
# ds.get('ImagePositionPatient')[-1] = '1566.0'
# ds.get('ImagePositionPatient')[-1] = '1566.5'
# ds.get('ImagePositionPatient')[-1] = '1567.0'
# ds.get('ImagePositionPatient')[-1] = '1567.5'
# ds.get('ImagePositionPatient')[-1] = '1568.0'
# ds.get('ImagePositionPatient')[-1] = '1568.5'
# ds.get('ImagePositionPatient')[-1] = '1569.0'
# ds.get('ImagePositionPatient')[-1] = '1569.5'
# ds.get('ImagePositionPatient')[-1] = '1570.0'
# ds.get('ImagePositionPatient')[-1] = '1570.5'
# ds.get('ImagePositionPatient')[-1] = '1571.0'
# ds.get('ImagePositionPatient')[-1] = '1571.5'
# ds.get('ImagePositionPatient')[-1] = '1572.0'
# ds.get('ImagePositionPatient')[-1] = '1572.5'
# ds.get('ImagePositionPatient')[-1] = '1573.0'
# ds.get('ImagePositionPatient')[-1] = '1573.5'
# ds.get('ImagePositionPatient')[-1] = '1574.0'
# ds.get('ImagePositionPatient')[-1] = '1574.5'
# ds.get('ImagePositionPatient')[-1] = '1575.0'
# ds.get('ImagePositionPatient')[-1] = '1575.5'
# ds.get('ImagePositionPatient')[-1] = '1576.0'
# ds.get('ImagePositionPatient')[-1] = '1576.5'
# ds.get('ImagePositionPatient')[-1] = '1577.0'
# ds.get('ImagePositionPatient')[-1] = '1577.5'
# ds.get('ImagePositionPatient')[-1] = '1578.0'
# ds.get('ImagePositionPatient')[-1] = '1578.5'
# ds.get('ImagePositionPatient')[-1] = '1579.0'
# ds.get('ImagePositionPatient')[-1] = '1579.5'
# ds.get('ImagePositionPatient')[-1] = '1580.0'
# ds.get('ImagePositionPatient')[-1] = '1580.5'
# ds.get('ImagePositionPatient')[-1] = '1581.0'
# ds.get('ImagePositionPatient')[-1] = '1581.5'
# ds.get('ImagePositionPatient')[-1] = '1582.0'
# ds.get('ImagePositionPatient')[-1] = '1582.5'
# ds.get('ImagePositionPatient')[-1] = '1583.0'
# ds.get('ImagePositionPatient')[-1] = '1583.5'
# ds.get('ImagePositionPatient')[-1] = '1584.0'
# ds.get('ImagePositionPatient')[-1] = '1584.5'
# ds.get('ImagePositionPatient')[-1] = '1585.0'
# ds.get('ImagePositionPatient')[-1] = '1585.5'
# ds.get('ImagePositionPatient')[-1] = '1586.0'
# ds.get('ImagePositionPatient')[-1] = '1586.5'
# ds.get('ImagePositionPatient')[-1] = '1587.0'
# ds.get('ImagePositionPatient')[-1] = '1587.5'
# ds.get('ImagePositionPatient')[-1] = '1588.0'
# ds.get('ImagePositionPatient')[-1] = '1588.5'
# ds.get('ImagePositionPatient')[-1] = '1589.0'
# ds.get('ImagePositionPatient')[-1] = '1589.5'
# ds.get('ImagePositionPatient')[-1] = '1590.0'
# ds.get('ImagePositionPatient')[-1] = '1590.5'
# ds.get('ImagePositionPatient')[-1] = '1591.0'
# ds.get('ImagePositionPatient')[-1] = '1591.5'
# ds.get('ImagePositionPatient')[-1] = '1592.0'
# ds.get('ImagePositionPatient')[-1] = '1592.5'
# ds.get('ImagePositionPatient')[-1] = '1593.0'
# ds.get('ImagePositionPatient')[-1] = '1593.5'
# ds.get('ImagePositionPatient')[-1] = '1594.0'
# ds.get('ImagePositionPatient')[-1] = '1594.5'
# ds.get('ImagePositionPatient')[-1] = '1595.0'
# ds.get('ImagePositionPatient')[-1] = '1595.5'
# ds.get('ImagePositionPatient')[-1] = '1596.0'
# ds.get('ImagePositionPatient')[-1] = '1596.5'
# ds.get('ImagePositionPatient')[-1] = '1597.0'
# ds.get('ImagePositionPatient')[-1] = '1597.5'
# ds.get('ImagePositionPatient')[-1] = '1598.0'
# ds.get('ImagePositionPatient')[-1] = '1598.5'
# ds.get('ImagePositionPatient')[-1] = '1599.0'
# ds.get('ImagePositionPatient')[-1] = '1599.5'
# ds.get('ImagePositionPatient')[-1] = '1600.0'
# ds.get('ImagePositionPatient')[-1] = '1600.5'
# ds.get('ImagePositionPatient')[-1] = '1601.0'
# ds.get('ImagePositionPatient')[-1] = '1601.5'
# ds.get('ImagePositionPatient')[-1] = '1602.0'
# ds.get('ImagePositionPatient')[-1] = '1602.5'
# ds.get('ImagePositionPatient')[-1] = '1603.0'
# ds.get('ImagePositionPatient')[-1] = '1603.5'
# ds.get('ImagePositionPatient')[-1] = '1604.0'
# ds.get('ImagePositionPatient')[-1] = '1604.5'
# ds.get('ImagePositionPatient')[-1] = '1605.0'
# ds.get('ImagePositionPatient')[-1] = '1605.5'
# ds.get('ImagePositionPatient')[-1] = '1606.0'
# ds.get('ImagePositionPatient')[-1] = '1606.5'
# ds.get('ImagePositionPatient')[-1] = '1607.0'
# ds.get('ImagePositionPatient')[-1] = '1607.5'
# ds.get('ImagePositionPatient')[-1] = '1608.0'
# ds.get('ImagePositionPatient')[-1] = '1608.5'
# ds.get('ImagePositionPatient')[-1] = '1609.0'
# ds.get('ImagePositionPatient')[-1] = '1609.5'
# ds.get('ImagePositionPatient')[-1] = '1610.0'
# ds.get('ImagePositionPatient')[-1] = '1610.5'
# ds.get('ImagePositionPatient')[-1] = '1611.0'
# ds.get('ImagePositionPatient')[-1] = '1611.5'
# ds.get('ImagePositionPatient')[-1] = '1612.0'
# ds.get('ImagePositionPatient')[-1] = '1612.5'
# ds.get('ImagePositionPatient')[-1] = '1613.0'
# ds.get('ImagePositionPatient')[-1] = '1613.5'
# ds.get('ImagePositionPatient')[-1] = '1614.0'
# ds.get('ImagePositionPatient')[-1] = '1614.5'
# ds.get('ImagePositionPatient')[-1] = '1615.0'
# ds.get('ImagePositionPatient')[-1] = '1615.5'
# ds.get('ImagePositionPatient')[-1] = '1616.0'
# ds.get('ImagePositionPatient')[-1] = '1616.5'
# ds.get('ImagePositionPatient')[-1] = '1617.0'
# ds.get('ImagePositionPatient')[-1] = '1617.5'
# ds.get('ImagePositionPatient')[-1] = '1618.0'
# ds.get('ImagePositionPatient')[-1] = '1618.5'
# ds.get('ImagePositionPatient')[-1] = '1619.0'
# ds.get('ImagePositionPatient')[-1] = '1619.5'
# ds.get('ImagePositionPatient')[-1] = '1620.0'
# ds.get('ImagePositionPatient')[-1] = '1620.5'
# ds.get('ImagePositionPatient')[-1] = '1621.0'
# ds.get('ImagePositionPatient')[-1] = '1621.5'
# ds.get('ImagePositionPatient')[-1] = '1622.0'
# ds.get('ImagePositionPatient')[-1] = '1622.5'
# ds.get('ImagePositionPatient')[-1] = '1623.0'
# ds.get('ImagePositionPatient')[-1] = '1623.5'
# ds.get('ImagePositionPatient')[-1] = '1624.0'
# ds.get('ImagePositionPatient')[-1] = '1624.5'
# ds.get('ImagePositionPatient')[-1] = '1625.0'
# ds.get('ImagePositionPatient')[-1] = '1625.5'
# ds.get('ImagePositionPatient')[-1] = '1626.0'
# ds.get('ImagePositionPatient')[-1] = '1626.5'
# ds.get('ImagePositionPatient')[-1] = '1627.0'
# ds.get('ImagePositionPatient')[-1] = '1627.5'
# ds.get('ImagePositionPatient')[-1] = '1628.0'
# ds.get('ImagePositionPatient')[-1] = '1628.5'
# ds.get('ImagePositionPatient')[-1] = '1629.0'
# ds.get('ImagePositionPatient')[-1] = '1629.5'
# ds.get('ImagePositionPatient')[-1] = '1630.0'
# ds.get('ImagePositionPatient')[-1] = '1630.5'
# ds.get('ImagePositionPatient')[-1] = '1631.0'
# ds.get('ImagePositionPatient')[-1] = '1631.5'
# ds.get('ImagePositionPatient')[-1] = '1632.0'
# ds.get('ImagePositionPatient')[-1] = '1632.5'
# ds.get('ImagePositionPatient')[-1] = '1633.0'
# ds.get('ImagePositionPatient')[-1] = '1633.5'
# ds.get('ImagePositionPatient')[-1] = '1634.0'
# ds.get('ImagePositionPatient')[-1] = '1634.5'
# ds.get('ImagePositionPatient')[-1] = '1635.0'
# ds.get('ImagePositionPatient')[-1] = '1635.5'
# ds.get('ImagePositionPatient')[-1] = '1636.0'
# ds.get('ImagePositionPatient')[-1] = '1636.5'
# ds.get('ImagePositionPatient')[-1] = '1637.0'
# ds.get('ImagePositionPatient')[-1] = '1637.5'
# ds.get('ImagePositionPatient')[-1] = '1638.0'
# ds.get('ImagePositionPatient')[-1] = '1638.5'
# ds.get('ImagePositionPatient')[-1] = '1639.0'
# ds.get('ImagePositionPatient')[-1] = '1639.5'
# ds.get('ImagePositionPatient')[-1] = '1640.0'
# ds.get('ImagePositionPatient')[-1] = '1640.5'
# ds.get('ImagePositionPatient')[-1] = '1641.0'
# ds.get('ImagePositionPatient')[-1] = '1641.5'
# ds.get('ImagePositionPatient')[-1] = '1642.0'
# ds.get('ImagePositionPatient')[-1] = '1642.5'
# ds.get('ImagePositionPatient')[-1] = '1643.0'
# ds.get('ImagePositionPatient')[-1] = '1643.5'
# ds.get('ImagePositionPatient')[-1] = '1644.0'
# ds.get('ImagePositionPatient')[-1] = '1644.5'
# ds.get('ImagePositionPatient')[-1] = '1645.0'
# ds.get('ImagePositionPatient')[-1] = '1645.5'
# ds.get('ImagePositionPatient')[-1] = '1646.0'
# ds.get('ImagePositionPatient')[-1] = '1646.5'
# ds.get('ImagePositionPatient')[-1] = '1647.0'
# ds.get('ImagePositionPatient')[-1] = '1647.5'
# ds.get('ImagePositionPatient')[-1] = '1648.0'
# ds.get('ImagePositionPatient')[-1] = '1648.5'
# ds.get('ImagePositionPatient')[-1] = '1649.0'
# ds.get('ImagePositionPatient')[-1] = '1649.5'
# ds.get('ImagePositionPatient')[-1] = '1650.0'
# ds.get('ImagePositionPatient')[-1] = '1650.5'
# ds.get('ImagePositionPatient')[-1] = '1651.0'
# ds.get('ImagePositionPatient')[-1] = '1651.5'
# ds.get('ImagePositionPatient')[-1] = '1652.0'
# ds.get('ImagePositionPatient')[-1] = '1652.5'
# ds.get('ImagePositionPatient')[-1] = '1653.0'
# ds.get('ImagePositionPatient')[-1] = '1653.5'
# ds.get('ImagePositionPatient')[-1] = '1654.0'
# ds.get('ImagePositionPatient')[-1] = '1654.5'
# ds.get('ImagePositionPatient')[-1] = '1655.0'
# ds.get('ImagePositionPatient')[-1] = '1655.5'
# ds.get('ImagePositionPatient')[-1] = '1656.0'
# ds.get('ImagePositionPatient')[-1] = '1656.5'
# ds.get('ImagePositionPatient')[-1] = '1657.0'
# ds.get('ImagePositionPatient')[-1] = '1657.5'
# ds.get('ImagePositionPatient')[-1] = '1658.0'
# ds.get('ImagePositionPatient')[-1] = '1658.5'
# ds.get('ImagePositionPatient')[-1] = '1659.0'
# ds.get('ImagePositionPatient')[-1] = '1659.5'
# ds.get('ImagePositionPatient')[-1] = '1660.0'
# ds.get('ImagePositionPatient')[-1] = '1660.5'
# ds.get('ImagePositionPatient')[-1] = '1661.0'
# ds.get('ImagePositionPatient')[-1] = '1661.5'
# ds.get('ImagePositionPatient')[-1] = '1662.0'
# ds.get('ImagePositionPatient')[-1] = '1662.5'
# ds.get('ImagePositionPatient')[-1] = '1663.0'
# ds.get('ImagePositionPatient')[-1] = '1663.5'
# ds.get('ImagePositionPatient')[-1] = '1664.0'
# ds.get('ImagePositionPatient')[-1] = '1664.5'
# ds.get('ImagePositionPatient')[-1] = '1665.0'
# ds.get('ImagePositionPatient')[-1] = '1665.5'
# ds.get('ImagePositionPatient')[-1] = '1666.0'
# ds.get('ImagePositionPatient')[-1] = '1666.5'
# ds.get('ImagePositionPatient')[-1] = '1667.0'
# ds.get('ImagePositionPatient')[-1] = '1667.5'
# ds.get('ImagePositionPatient')[-1] = '1668.0'
# ds.get('ImagePositionPatient')[-1] = '1668.5'
# ds.get('ImagePositionPatient')[-1] = '1669.0'
# ds.get('ImagePositionPatient')[-1] = '1669.5'
# ds.get('ImagePositionPatient')[-1] = '1670.0'
# ds.get('ImagePositionPatient')[-1] = '1670.5'
# ds.get('ImagePositionPatient')[-1] = '1671.0'
# ds.get('ImagePositionPatient')[-1] = '1671.5'
# ds.get('ImagePositionPatient')[-1] = '1672.0'
# ds.get('ImagePositionPatient')[-1] = '1672.5'
# ds.get('ImagePositionPatient')[-1] = '1673.0'
# ds.get('ImagePositionPatient')[-1] = '1673.5'
# ds.get('ImagePositionPatient')[-1] = '1674.0'
# ds.get('ImagePositionPatient')[-1] = '1674.5'
# ds.get('ImagePositionPatient')[-1] = '1675.0'
# ds.get('ImagePositionPatient')[-1] = '1675.5'
# ds.get('ImagePositionPatient')[-1] = '1676.0'
# ds.get('ImagePositionPatient')[-1] = '1676.5'
# ds.get('ImagePositionPatient')[-1] = '1677.0'
# ds.get('ImagePositionPatient')[-1] = '1677.5'
# ds.get('ImagePositionPatient')[-1] = '1678.0'
# ds.get('ImagePositionPatient')[-1] = '1678.5'
# ds.get('ImagePositionPatient')[-1] = '1679.0'
# ds.get('ImagePositionPatient')[-1] = '1679.5'
# ds.get('ImagePositionPatient')[-1] = '1680.0'
# ds.get('ImagePositionPatient')[-1] = '1680.5'
# ds.get('ImagePositionPatient')[-1] = '1681.0'
# ds.get('ImagePositionPatient')[-1] = '1681.5'
# ds.get('ImagePositionPatient')[-1] = '1682.0'
# ds.get('ImagePositionPatient')[-1] = '1682.5'
# ds.get('ImagePositionPatient')[-1] = '1683.0'
# ds.get('ImagePositionPatient')[-1] = '1683.5'
# ds.get('ImagePositionPatient')[-1] = '1684.0'
# ds.get('ImagePositionPatient')[-1] = '1684.5'
# ds.get('ImagePositionPatient')[-1] = '1685.0'
# ds.get('ImagePositionPatient')[-1] = '1685.5'
# ds.get('ImagePositionPatient')[-1] = '1686.0'
# ds.get('ImagePositionPatient')[-1] = '1686.5'
# ds.get('ImagePositionPatient')[-1] = '1687.0'
# ds.get('ImagePositionPatient')[-1] = '1687.5'
# ds.get('ImagePositionPatient')[-1] = '1688.0'
# ds.get('ImagePositionPatient')[-1] = '1688.5'
# ds.get('ImagePositionPatient')[-1] = '1689.0'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-026887e03591> in <module>
#       1 paths_list = list(saved_dirpath.glob("*.dcm"))
# ----> 2 path_to_nifti_file, meta_list = DICOMToNIfTI(paths_list).convert()
#
# <ipython-input-1-a62f3d671696> in convert(self)
#      27         volm, meta_list = [], []
#      28         for ds in ds_list:
# ---> 29             volm.append(ds.pixel_array)
#      30             meta_list.append({
#      31                 'patient_id': ds.get('PatientID'),
#
# ~\anaconda3\lib\site-packages\pydicom\dataset.py in __getattr__(self, name)
#     906             return {}
#     907         # Try the base class attribute getter (fix for issue 332)
# --> 908         return object.__getattribute__(self, name)
#     909
#     910     @property
#
# ~\anaconda3\lib\site-packages\pydicom\dataset.py in pixel_array(self)
#    1953             :class:`numpy.ndarray`.
#    1954         """
# -> 1955         self.convert_pixel_data()
#    1956         return cast("numpy.ndarray", self._pixel_array)
#    1957
#
# ~\anaconda3\lib\site-packages\pydicom\dataset.py in convert_pixel_data(self, handler_name)
#    1510             self._convert_pixel_data_using_handler(handler_name)
#    1511         else:
# -> 1512             self._convert_pixel_data_without_handler()
#    1513
#    1514     def _convert_pixel_data_using_handler(self, name: str) -> None:
#
# ~\anaconda3\lib\site-packages\pydicom\dataset.py in _convert_pixel_data_without_handler(self)
#    1622             .format(", ".join([str(hh) for hh in available_handlers]))
#    1623         )
# -> 1624         raise last_exception  # type: ignore[misc]
#    1625
#    1626     def _do_pixel_data_conversion(self, handler: Any) -> None:
#
# ~\anaconda3\lib\site-packages\pydicom\dataset.py in _convert_pixel_data_without_handler(self)
#    1602         for handler in available_handlers:
#    1603             try:
# -> 1604                 self._do_pixel_data_conversion(handler)
#    1605                 return
#    1606             except Exception as exc:
#
# ~\anaconda3\lib\site-packages\pydicom\dataset.py in _do_pixel_data_conversion(self, handler)
#    1629         # Use the handler to get a 1D numpy array of the pixel data
#    1630         # Will raise an exception if no pixel data element
# -> 1631         arr = handler.get_pixeldata(self)
#    1632         self._pixel_array = reshape_pixel_array(self, arr)
#    1633
#
# ~\anaconda3\lib\site-packages\pydicom\pixel_data_handlers\pylibjpeg_handler.py in get_pixeldata(ds)
#     325
#     326     generate_offsets = range(0, expected_len, frame_len)
# --> 327     for frame, offset in zip(generate_frames(ds, False), generate_offsets):
#     328         arr[offset:offset + frame_len] = frame
#     329
#
# ~\anaconda3\lib\site-packages\pydicom\pixel_data_handlers\pylibjpeg_handler.py in generate_frames(ds, reshape)
#     245     missing = [elem for elem in required_elements if elem not in ds]
#     246     if missing:
# --> 247         raise AttributeError(
#     248             "Unable to convert the pixel data as the following required "
#     249             "elements are missing from the dataset: " + ", ".join(missing)
#
# AttributeError: Unable to convert the pixel data as the following required elements are missing from the dataset: PhotometricInterpretation, PixelData
